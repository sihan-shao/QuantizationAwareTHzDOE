# %%
import torch
import torchvision
from torchvision import transforms
from torchvision.transforms import Resize, ToTensor, Pad
import sys
sys.path.append('../')
from DataType.ElectricField import ElectricField
from LightSource.Gaussian_beam import Guassian_beam
from Props.ASM_Prop import ASM_prop
from Props.RSC_Prop import RSC_prop
from Components.Thin_Lens import Thin_LensElement
from Components.Aperture import ApertureElement
from Components.QuantizedDOE import SoftGumbelQuantizedDOELayerv3 as SoftGumbelQuantizedDOELayer
from Components.QuantizedDOE import NaiveGumbelQuantizedDOELayer
from Components.QuantizedDOE import PSQuantizedDOELayer
from Components.QuantizedDOE import STEQuantizedDOELayer
from Components.QuantizedDOE import FullPrecisionDOELayer
from Components.QuantizedDOE import FixDOEElement
from utils.Helper_Functions import normalize, DOE_xyz_cordinates_Generator
from utils.units import *
import numpy as np
import scipy.io
import os
import time
import torch.nn as nn
import matplotlib.pyplot as plt

# %% [markdown]
# # 1. Set simulation parameters

# %%
# Hologram parameters (high-temp resin)
epsilon = 2.66
tand = 0.003
    
input_field_shape = [100, 100]
input_dxy = 1 * mm
doe_shape = [100, 100]
doe_dxy = 1 * mm
    
    
c0 = 2.998e8
f2 = 300e9  # 0.3 THz

wavelengths = c0 / f2
#print("The number of wavelengths: " +  str(wavelengths.shape[0]))

# all parameters of DOE optimization
doe_params = {
    'doe_size': doe_shape,
    'doe_dxy' : doe_dxy,
    'doe_level': 4,
    'look_up_table': [0*mm, 0.2*mm, 0.4*mm, 0.6*mm],
    'num_unit': None,
    'height_constraint_max': 0.8 * mm,
    'tolerance': 10 * um,  
    'material': [epsilon, tand]
}

optim_params = {
    'c_s': 100,   # a number to boost the score (higher more robust to gumbel noise)
    'tau_max': 2.5, # maximum value of tau
    'tau_min': 1.5  # minimum value of tau
}


# layer num and distance between two layer
num_layer = 4
d_layer = 20 * mm

# training parameter
batch_size = 128

# %% [markdown]
# # 2. Define a 3-layers diffractive optical neural network (DONN)

# %%
class DONN(nn.Module):
    """ simulate a diffractive optical neural network with multiple DOEs
        various quantized optimization method can be used here
    """
    def __init__(self, 
                 input_dxy, 
                 input_field_shape,
                 doe_params, 
                 optim_params,
                 wavelengths, 
                 num_layer, 
                 d_layer,
                 q_method,
                 device='cuda:0'):
        super().__init__()
        
        self.input_dxy = input_dxy
        self.input_field_shape = input_field_shape
        self.doe_params = doe_params
        self.optim_params = optim_params
        
        self.wavelengths = wavelengths

        self.num_layer = num_layer
        self.d_layer = d_layer

        
        self.asm_prop2layer = ASM_prop(z_distance=30 * mm, 
                                       bandlimit_type='exact', 
                                       padding_scale=2, 
                                       bandlimit_kernel=True)

        self.aperture = ApertureElement(aperture_type = 'rect',
                                        aperture_size = 0.08)

        self.device = device

        self.iter_frac = None
        
        # define the difffractive layers
        self.asm_prop_layers = nn.ModuleList([
                                    ASM_prop(z_distance=self.d_layer, 
                                             bandlimit_type='exact', 
                                             padding_scale=2, 
                                             bandlimit_kernel=True) for i in range(self.num_layer)
                                    ])
        if q_method == None:
            self.does = nn.ModuleList([FullPrecisionDOELayer(self.doe_params) for i in range(self.num_layer)])
            
        elif q_method == 'sgs':
            self.does = nn.ModuleList([SoftGumbelQuantizedDOELayer(self.doe_params, self.optim_params) for i in range(self.num_layer)])
            
        elif q_method == 'gs':
            self.does = nn.ModuleList([NaiveGumbelQuantizedDOELayer(self.doe_params, self.optim_params) for i in range(self.num_layer)])
            
        elif q_method == 'psq':
            optim_params = {'c_s': 300,'tau_max': 50,'tau_min': 1}
            self.does = nn.ModuleList([PSQuantizedDOELayer(self.doe_params, optim_params) for i in range(self.num_layer)])
            
        elif q_method == 'ste':
            self.does = nn.ModuleList([STEQuantizedDOELayer(self.doe_params, self.optim_params) for i in range(self.num_layer)])

    def encode_object(self, u):
        # Create plane wave
        amplitude_fields = torch.ones(1, 1, self.input_field_shape[0], self.input_field_shape[1], device=self.device) * u
        phase_fields = torch.zeros_like(amplitude_fields, device=self.device)
        # Combine amplitude and phase to form complex electric fields
        electric_fields = amplitude_fields * torch.exp(1j * phase_fields) # add Batch dimension

        field = ElectricField(
                data=electric_fields, 
                wavelengths=self.wavelengths,
                spacing=self.input_dxy
        )
        
        field = self.asm_prop2layer(field)
        field = self.aperture(field)
        
        return field
    
    def forward(self, u, iter_frac=None):

        self.iter_frac = iter_frac
        field = self.encode_object(u)
        #print(iter_frac)

        for i in range(self.num_layer):
            field = self.does[i](field, self.iter_frac)
            field = self.asm_prop_layers[i](field)
            field = self.aperture(field)
    
        return field

# %%
donn = DONN(input_dxy=input_dxy, 
            input_field_shape=input_field_shape, 
            doe_params=doe_params, 
            optim_params=optim_params,
            wavelengths=wavelengths, 
            num_layer=num_layer,
            d_layer=d_layer, 
            q_method=None)

# %%
donn
# Out:
# DONN(
#   (asm_prop2layer): ASM_prop()
#   (aperture): ApertureElement()
#   (asm_prop_layers): ModuleList(
#     (0-3): 4 x ASM_prop()
#   )
#   (does): ModuleList(
#     (0-3): 4 x FullPrecisionDOELayer()
#   )
# )

# %% [markdown]
# # 3. Define a Label Generator and Dataloader

# %% [markdown]
# ## 3.1 MINST Dataloader

# %%
import torch
import torchvision.transforms as transforms
from PIL import Image

def thresholding(image):
    # Convert image to a PyTorch tensor
    image_tensor = transforms.functional.to_tensor(image)
    
    # Apply a threshold (e.g., 0.5 for the middle intensity in normalized range)
    binary_tensor = (image_tensor > 0.4).float()
    
    # Convert tensor back to PIL image
    return transforms.functional.to_pil_image(binary_tensor)

trans =transforms.Compose([Resize(80), Pad(10), transforms.Lambda(thresholding), ToTensor()])

mnist_train = torchvision.datasets.MNIST(
        root="./data", train=True, transform=trans, download=True)
mnist_test = torchvision.datasets.MNIST(
        root="./data", train=False, transform=trans, download=True) 
train_set, val_set = torch.utils.data.random_split(mnist_train, [len(mnist_train)-5000, 5000])
    
# train, validation and test
train_loader = torch.utils.data.DataLoader(train_set, 
                                           batch_size=batch_size,
                                           shuffle=True, num_workers=8,pin_memory=True)
val_loader = torch.utils.data.DataLoader(val_set, 
                                         batch_size=batch_size,
                                         shuffle=True, num_workers=4)

test_loader = torch.utils.data.DataLoader(mnist_test, 
                                         batch_size=batch_size,
                                         shuffle=True, num_workers=4)

# %%
# Function to visualize images
dataiter = iter(train_loader)
images, labels = next(dataiter)

plt.imshow(images[0, 0, :, :])

len(mnist_test)
# Out:
# 10000

# %% [markdown]
# ## 3.2 Label Gemerator

# %%
def rect(X,w):
    Y = torch.zeros(X.shape)
    Y[torch.abs(X)<w]=1
    return Y.cuda()

L = 100
M = 100
dx = L/M
x1 = torch.linspace(-L/2, L/2, M)
X1, Y1 = torch.meshgrid(x1, x1, indexing='ij')
w = 3
yb = 12
xb = 12

cens = [[-xb, yb],[0, yb], [xb, yb],
        [-xb/2-xb,0],[-xb/2,0],[xb/2,0],[xb/2+xb,0],
        [-xb, -yb],[0, -yb], [xb, -yb]]
cens2 = [] 
w2 = int( w*M/L+1)
# labels = label_generator()
for x, y in cens:
    cens2.append([int(M/2+x/L*M),int(M/2+y/L*M)]) 

def label_generator():

    labels = torch.zeros(10,M,M)
    for k in range(10):
        labels[k] = rect(X1-cens[k][0],w)*rect(Y1-cens[k][1],w)
    return labels.unsqueeze(1)


def eval_accuracy(target, label):
        
    label_hat = torch.zeros(target.size(0), 10).cuda()
    # print(label_hat[:,1].size())
    for k in range(10):
        x, y = cens2[k]
        # label_hat[:,k] = target[:, :, y-w2:y+w2, x-w2:x+w2].sum(dim=(2,3)).squeeze(1)
        label_hat[:,k] = target[:, :, x-w2:x+w2, y-w2:y+w2].sum(dim=(2,3)).squeeze(1)          
    # print(label_hat.size())
    label_hat = label_hat.argmax(1)
    acc = (label_hat == label.cuda()).sum()/label.size(0)
    
    return acc.data, label_hat

# %%
test = torch.tensor([0,1,1,3,4,3,6,7,8,9])
a = label_generator()
target = a[test]
acc = eval_accuracy(target, test)
a = torch.sum(a, axis=0)
plt.imshow(a[0],cmap='gray')

# %% [markdown]
# ## 3.3 define loss function

# %%
def npcc_loss(X, Y):
    X_mean = torch.mean(X, dim=(2,3), keepdim=True)
    Y_mean = torch.mean(Y,dim=(2,3), keepdim=True) 
    a = torch.sum((X - X_mean)*(Y - Y_mean), dim=(2,3), keepdim=True)
    b = torch.sqrt(torch.sum((X - X_mean)**2, dim=(2,3), keepdim=True)
                   *torch.sum((Y - Y_mean)**2, dim=(2,3), keepdim=True))
    npcc = torch.mean(-a/b)
    return npcc

# %% [markdown]
# # 4. Define a train and validation pipelines

# %%
def train(onn,
          criterion, 
          optimizer, 
          train_loader,
          val_loader,
          save_path,
          epoch_num=50,
          device='cuda:0'):
    
    label_set = label_generator()
    train_losses = []
    train_accies = []
    val_losses = []
    val_accies = []

    for epoch in range(1, epoch_num+1):  
        train_loss = 0.0
        acc_sum = 0.0
        for i, data in enumerate(train_loader, 0):
            inputs, labels = data
            inputs = inputs.to(device)
            # labels = labels.to(device)
            targets = label_set[labels]
            targets = targets.to(device)
            optimizer.zero_grad()
            outputs = onn(inputs, iter_frac=epoch/epoch_num)
            I = normalize(torch.abs(outputs.data)**2)
      
            loss = criterion(I, targets)
            loss.backward()

            optimizer.step()

            train_loss += loss.item()
            train_acc, label_hat= eval_accuracy(I ,labels)
            acc_sum += train_acc.item()
           
            if (i+1) % 200 == 0:    # print every 2000 mini-batches
                # acc = accuracy(outputs, labels)
                train_log = f'epoch {epoch } {i+1}, train loss: {train_loss/200: 5f},train accuracy: {acc_sum/200: 5f}'
    
                train_losses.append(train_loss /200)
                train_accies.append(acc_sum/200)
                train_loss = 0.0
                acc_sum = 0.0
                torch.save(onn, save_path+'/onn_psq'+str(epoch+1)+'.pt')
                with torch.no_grad():
                    val_loss, val_acc, I_val, labels_val = validation(onn, val_loader,criterion, iter_frac=epoch/epoch_num)
                    val_log =f'validation loss:{val_loss :5f}, validation accuracy: {val_acc:5f}'
                    val_losses.append(val_loss)
                    val_accies.append(val_acc)
                print(train_log,'\n', val_log)
                with open(save_path + '/log.txt', "a", encoding='utf-8') as f:
                    f.write(train_log+'\n')
                    f.write(val_log+'\n')
    return onn, train_losses, train_accies, val_losses, val_accies, I_val, labels_val

# %%
def validation(onn, val_loader,criterion, iter_frac, device='cuda:0'):
    val_loss_sum = .0
    val_acc_sum = .0
    label_set = label_generator()
    for i, data in enumerate(val_loader, 0):
        inputs, labels = data
        inputs = inputs.to(device)
        targets = label_set[labels]
        targets = targets.to(device)
        outputs = onn(inputs, iter_frac)
        I = normalize(torch.abs(outputs.data)**2)
        val_loss = criterion(I, targets)
        val_acc, _= eval_accuracy(I ,labels)
        val_loss_sum += val_loss.item()
        val_acc_sum += val_acc.item()
        
    return val_loss_sum/(i+1), val_acc_sum/(i+1), I, labels


def conf_matrix(onn, val_loader, criterion, iter_frac=1, device='cuda:0'):
    from sklearn.metrics import confusion_matrix
    val_loss_sum = .0
    val_acc_sum = .0
    all_labels = []
    all_preds = []
    label_set = label_generator()
    
    for i, data in enumerate(val_loader, 0):
        inputs, labels = data
        inputs = inputs.to(device)
        targets = label_set[labels]
        targets = targets.to(device)
        outputs = onn(inputs, iter_frac)
        I = normalize(torch.abs(outputs.data)**2)
        val_loss = criterion(I, targets)
        val_acc, preds = eval_accuracy(I, labels)
        
        val_loss_sum += val_loss.item()
        val_acc_sum += val_acc.item()
        
        # Collect the true labels and predictions
        all_labels.append(labels.cpu().numpy())
        all_preds.append(preds.cpu().numpy())
    
    # Convert lists to numpy arrays
    all_labels = np.concatenate(all_labels)
    all_preds = np.concatenate(all_preds)
    
    # Compute confusion matrix
    conf_matrix = confusion_matrix(all_labels, all_preds)
    
    return conf_matrix, val_acc_sum/(i+1), I, labels

# %%
# 5. Training the model with different quantized methods

from torch import optim

################ train ###############################
file_path = 'model'
if os.path.exists(file_path) == False:
    os.makedirs(file_path)

device = 'cuda:0' if torch.cuda.is_available() else 'cpu'

donn = DONN(input_dxy=input_dxy, 
            input_field_shape=input_field_shape, 
            doe_params=doe_params, 
            optim_params=optim_params,
            wavelengths=wavelengths, 
            num_layer=num_layer,
            d_layer=d_layer, 
            q_method='psq', 
            device=device)

epoch_num = 50
optimizer = optim.AdamW(donn.parameters(), lr=0.1)
criterion = npcc_loss

################################ train ####################################
start_time = time.time()
donn, train_losses, train_accies, val_losses, val_accies, I_val, labels_val =\
            train(donn,criterion, optimizer,
                  train_loader,val_loader, 
                  file_path, epoch_num)    
    
end_time = time.time()
print(f'runing time: {end_time - start_time: 5f}s')
# Out:
# The critical distance is [0.26003873] m, the TF will be fine during the sampling !
# The critical distance is [0.26003873] m, the TF will be fine during the sampling !
# The critical distance is [0.26003873] m, the TF will be fine during the sampling !
# The critical distance is [0.26003873] m, the TF will be fine during the sampling !
# The critical distance is [0.26003873] m, the TF will be fine during the sampling !
# epoch 1 200, train loss: -0.534611,train accuracy:  0.721094
#  validation loss:-0.589961, validation accuracy: 0.784961
# epoch 1 400, train loss: -0.596152,train accuracy:  0.783477
#  validation loss:-0.603048, validation accuracy: 0.788086
# epoch 2 200, train loss: -0.619568,train accuracy:  0.797148
#  validation loss:-0.626201, validation accuracy: 0.806250
# epoch 2 400, train loss: -0.623273,train accuracy:  0.801953
#  validation loss:-0.626082, validation accuracy: 0.813672
# epoch 3 200, train loss: -0.630897,train accuracy:  0.805039
#  validation loss:-0.634687, validation accuracy: 0.810937
# epoch 3 400, train loss: -0.635004,train accuracy:  0.809102
#  validation loss:-0.639369, validation accuracy: 0.816406
# epoch 4 200, train loss: -0.638304,train accuracy:  0.809336
#  validation loss:-0.640917, validation accuracy: 0.816602
# epoch 4 400, train loss: -0.639731,train accuracy:  0.810469
#  validation loss:-0.640540, validation accuracy: 0.820703
# epoch 5 200, train loss: -0.642798,train accuracy:  0.815820
#  validation loss:-0.646050, validation accuracy: 0.827734
# epoch 5 400, train loss: -0.641574,train accuracy:  0.811289
#  validation loss:-0.646062, validation accuracy: 0.827148
# epoch 6 200, train loss: -0.642814,train accuracy:  0.810937
#  validation loss:-0.643992, validation accuracy: 0.818359
# epoch 6 400, train loss: -0.644378,train accuracy:  0.816602
#  validation loss:-0.647561, validation accuracy: 0.816602
# epoch 7 200, train loss: -0.643214,train accuracy:  0.813477
#  validation loss:-0.643840, validation accuracy: 0.808398
# epoch 7 400, train loss: -0.643755,train accuracy:  0.813984
#  validation loss:-0.645659, validation accuracy: 0.815234
# epoch 8 200, train loss: -0.642895,train accuracy:  0.812617
#  validation loss:-0.646244, validation accuracy: 0.821875
# epoch 8 400, train loss: -0.643245,train accuracy:  0.815156
#  validation loss:-0.646159, validation accuracy: 0.826367
# epoch 9 200, train loss: -0.643477,train accuracy:  0.813984
#  validation loss:-0.647341, validation accuracy: 0.827344
# epoch 9 400, train loss: -0.642817,train accuracy:  0.817383
#  validation loss:-0.642956, validation accuracy: 0.814648
# epoch 10 200, train loss: -0.642304,train accuracy:  0.818047
#  validation loss:-0.643038, validation accuracy: 0.811719
# epoch 10 400, train loss: -0.641377,train accuracy:  0.813516
#  validation loss:-0.645400, validation accuracy: 0.819336
# epoch 11 200, train loss: -0.640970,train accuracy:  0.812422
#  validation loss:-0.643862, validation accuracy: 0.816992
# epoch 11 400, train loss: -0.641689,train accuracy:  0.818750
#  validation loss:-0.644702, validation accuracy: 0.816797
# epoch 12 200, train loss: -0.639649,train accuracy:  0.815703
#  validation loss:-0.640385, validation accuracy: 0.820898
# epoch 12 400, train loss: -0.639448,train accuracy:  0.813164
#  validation loss:-0.643731, validation accuracy: 0.825000
# epoch 13 200, train loss: -0.638810,train accuracy:  0.813672
#  validation loss:-0.640219, validation accuracy: 0.822852
# epoch 13 400, train loss: -0.639004,train accuracy:  0.815234
#  validation loss:-0.637492, validation accuracy: 0.816602
# epoch 14 200, train loss: -0.637092,train accuracy:  0.815977
#  validation loss:-0.638132, validation accuracy: 0.819727
# epoch 14 400, train loss: -0.636777,train accuracy:  0.811602
#  validation loss:-0.635569, validation accuracy: 0.813867
# epoch 15 200, train loss: -0.636467,train accuracy:  0.814883
#  validation loss:-0.639244, validation accuracy: 0.820312
# epoch 15 400, train loss: -0.636673,train accuracy:  0.814531
#  validation loss:-0.637506, validation accuracy: 0.818164
# epoch 16 200, train loss: -0.633780,train accuracy:  0.813828
#  validation loss:-0.634087, validation accuracy: 0.822852
# epoch 16 400, train loss: -0.634743,train accuracy:  0.816523
#  validation loss:-0.637400, validation accuracy: 0.822852
# epoch 17 200, train loss: -0.631144,train accuracy:  0.813516
#  validation loss:-0.636202, validation accuracy: 0.823242
# epoch 17 400, train loss: -0.631720,train accuracy:  0.814609
#  validation loss:-0.633635, validation accuracy: 0.818359
# epoch 18 200, train loss: -0.629820,train accuracy:  0.811484
#  validation loss:-0.631255, validation accuracy: 0.817383
# epoch 18 400, train loss: -0.629033,train accuracy:  0.812344
#  validation loss:-0.628929, validation accuracy: 0.817773
# epoch 19 200, train loss: -0.626430,train accuracy:  0.814219
#  validation loss:-0.626884, validation accuracy: 0.807031
# epoch 19 400, train loss: -0.627329,train accuracy:  0.811758
#  validation loss:-0.625835, validation accuracy: 0.814648
# epoch 20 200, train loss: -0.624561,train accuracy:  0.814531
#  validation loss:-0.625951, validation accuracy: 0.818750
# epoch 20 400, train loss: -0.624370,train accuracy:  0.811445
#  validation loss:-0.624498, validation accuracy: 0.820312
# epoch 21 200, train loss: -0.622316,train accuracy:  0.813555
#  validation loss:-0.623138, validation accuracy: 0.818555
# epoch 21 400, train loss: -0.623158,train accuracy:  0.812656
#  validation loss:-0.625665, validation accuracy: 0.818164
# epoch 22 200, train loss: -0.620765,train accuracy:  0.814297
#  validation loss:-0.621808, validation accuracy: 0.814844
# epoch 22 400, train loss: -0.618791,train accuracy:  0.809883
#  validation loss:-0.613892, validation accuracy: 0.803516
# epoch 23 200, train loss: -0.614537,train accuracy:  0.807930
#  validation loss:-0.616236, validation accuracy: 0.819531
# epoch 23 400, train loss: -0.614801,train accuracy:  0.809414
#  validation loss:-0.615705, validation accuracy: 0.818750
# epoch 24 200, train loss: -0.612542,train accuracy:  0.810625
#  validation loss:-0.614325, validation accuracy: 0.823633
# epoch 24 400, train loss: -0.611413,train accuracy:  0.810508
#  validation loss:-0.610491, validation accuracy: 0.814453
# epoch 25 200, train loss: -0.610206,train accuracy:  0.808438
#  validation loss:-0.605277, validation accuracy: 0.801367
# epoch 25 400, train loss: -0.605384,train accuracy:  0.805547
#  validation loss:-0.607283, validation accuracy: 0.814648
# epoch 26 200, train loss: -0.605614,train accuracy:  0.809922
#  validation loss:-0.605394, validation accuracy: 0.809180
# epoch 26 400, train loss: -0.602488,train accuracy:  0.806133
#  validation loss:-0.604568, validation accuracy: 0.815039
# epoch 27 200, train loss: -0.602191,train accuracy:  0.808164
#  validation loss:-0.602554, validation accuracy: 0.814648
# epoch 27 400, train loss: -0.598537,train accuracy:  0.805391
#  validation loss:-0.601530, validation accuracy: 0.811719
# epoch 28 200, train loss: -0.596761,train accuracy:  0.805352
#  validation loss:-0.598126, validation accuracy: 0.815234
# epoch 28 400, train loss: -0.593189,train accuracy:  0.801875
#  validation loss:-0.596545, validation accuracy: 0.812500
# epoch 29 200, train loss: -0.590864,train accuracy:  0.798789
#  validation loss:-0.591140, validation accuracy: 0.800977
# epoch 29 400, train loss: -0.588852,train accuracy:  0.801953
#  validation loss:-0.590072, validation accuracy: 0.812305
# epoch 30 200, train loss: -0.587729,train accuracy:  0.803047
#  validation loss:-0.588516, validation accuracy: 0.806055
# epoch 30 400, train loss: -0.583615,train accuracy:  0.797852
#  validation loss:-0.586634, validation accuracy: 0.807031
# epoch 31 200, train loss: -0.580481,train accuracy:  0.798203
#  validation loss:-0.581819, validation accuracy: 0.804297
# epoch 31 400, train loss: -0.582028,train accuracy:  0.799453
#  validation loss:-0.581202, validation accuracy: 0.809961
# epoch 32 200, train loss: -0.577494,train accuracy:  0.798047
#  validation loss:-0.579580, validation accuracy: 0.812305
# epoch 32 400, train loss: -0.574761,train accuracy:  0.799141
#  validation loss:-0.575702, validation accuracy: 0.804297
# epoch 33 200, train loss: -0.571696,train accuracy:  0.795391
#  validation loss:-0.569250, validation accuracy: 0.797656
# epoch 33 400, train loss: -0.568835,train accuracy:  0.794102
#  validation loss:-0.573449, validation accuracy: 0.804688
# epoch 34 200, train loss: -0.567355,train accuracy:  0.792227
#  validation loss:-0.568748, validation accuracy: 0.801172
# epoch 34 400, train loss: -0.566223,train accuracy:  0.791484
#  validation loss:-0.565885, validation accuracy: 0.793359
# epoch 35 200, train loss: -0.562815,train accuracy:  0.792500
#  validation loss:-0.561547, validation accuracy: 0.799609
# epoch 35 400, train loss: -0.558877,train accuracy:  0.789141
#  validation loss:-0.557295, validation accuracy: 0.793945
# epoch 36 200, train loss: -0.555817,train accuracy:  0.790391
#  validation loss:-0.556587, validation accuracy: 0.797266
# epoch 36 400, train loss: -0.554143,train accuracy:  0.790469
#  validation loss:-0.554169, validation accuracy: 0.793750
# epoch 37 200, train loss: -0.552970,train accuracy:  0.791758
#  validation loss:-0.552390, validation accuracy: 0.792969
# epoch 37 400, train loss: -0.550407,train accuracy:  0.787461
#  validation loss:-0.551934, validation accuracy: 0.799023
# epoch 38 200, train loss: -0.546807,train accuracy:  0.783906
#  validation loss:-0.550109, validation accuracy: 0.798242
# epoch 38 400, train loss: -0.547788,train accuracy:  0.784805
#  validation loss:-0.544494, validation accuracy: 0.791992
# epoch 39 200, train loss: -0.542311,train accuracy:  0.780703
#  validation loss:-0.541157, validation accuracy: 0.790430
# epoch 39 400, train loss: -0.538584,train accuracy:  0.781836
#  validation loss:-0.538960, validation accuracy: 0.784375
# epoch 40 200, train loss: -0.537209,train accuracy:  0.776211
#  validation loss:-0.535133, validation accuracy: 0.779492
# epoch 40 400, train loss: -0.535550,train accuracy:  0.775430
#  validation loss:-0.533682, validation accuracy: 0.764648
# epoch 41 200, train loss: -0.534482,train accuracy:  0.777539
#  validation loss:-0.535269, validation accuracy: 0.780078
# epoch 41 400, train loss: -0.527827,train accuracy:  0.771758
#  validation loss:-0.526580, validation accuracy: 0.772852
# epoch 42 200, train loss: -0.525945,train accuracy:  0.772578
#  validation loss:-0.527374, validation accuracy: 0.779297
# epoch 42 400, train loss: -0.524330,train accuracy:  0.770234
#  validation loss:-0.526010, validation accuracy: 0.772656
# epoch 43 200, train loss: -0.520753,train accuracy:  0.764102
#  validation loss:-0.520168, validation accuracy: 0.772656
# epoch 43 400, train loss: -0.519051,train accuracy:  0.770703
#  validation loss:-0.515657, validation accuracy: 0.768359
# epoch 44 200, train loss: -0.515524,train accuracy:  0.766680
#  validation loss:-0.518347, validation accuracy: 0.779687
# epoch 44 400, train loss: -0.511695,train accuracy:  0.765547
#  validation loss:-0.513802, validation accuracy: 0.773242
# epoch 45 200, train loss: -0.511557,train accuracy:  0.766719
#  validation loss:-0.510033, validation accuracy: 0.769336
# epoch 45 400, train loss: -0.508868,train accuracy:  0.765156
#  validation loss:-0.509252, validation accuracy: 0.766602
# epoch 46 200, train loss: -0.506455,train accuracy:  0.766992
#  validation loss:-0.506923, validation accuracy: 0.764844
# epoch 46 400, train loss: -0.503530,train accuracy:  0.761289
#  validation loss:-0.501661, validation accuracy: 0.764062
# epoch 47 200, train loss: -0.499440,train accuracy:  0.756641
#  validation loss:-0.501165, validation accuracy: 0.763867
# epoch 47 400, train loss: -0.499399,train accuracy:  0.757070
#  validation loss:-0.498816, validation accuracy: 0.760547
# epoch 48 200, train loss: -0.495297,train accuracy:  0.748672
#  validation loss:-0.496209, validation accuracy: 0.755664
# epoch 48 400, train loss: -0.493709,train accuracy:  0.751328
#  validation loss:-0.496672, validation accuracy: 0.753906
# epoch 49 200, train loss: -0.491271,train accuracy:  0.739844
#  validation loss:-0.490976, validation accuracy: 0.739648
# epoch 49 400, train loss: -0.489620,train accuracy:  0.737734
#  validation loss:-0.495055, validation accuracy: 0.754492
# epoch 50 200, train loss: -0.488371,train accuracy:  0.728164
#  validation loss:-0.492125, validation accuracy: 0.734961
# epoch 50 400, train loss: -0.491704,train accuracy:  0.742383
#  validation loss:-0.489766, validation accuracy: 0.742578
# runing time:  2256.084959s

# %%
epochs = [k for k in range(1,epoch_num+1)] 
plt.figure(dpi = 300, figsize=(12,4))
plt.subplot(121)
plt.plot(epochs, train_losses, '-o')
plt.plot(epochs, val_losses, '-s')
plt.xlabel('epoch')
plt.ylabel('Loss')
plt.legend(['train','validation'])
plt.subplot(122)
plt.plot(epochs, train_accies, '-o')
plt.plot(epochs, val_accies, '-s')
plt.xlabel('epoch')
plt.ylabel('Accuracy')
plt.legend(['train','validation'])
plt.show()
    
plt.figure(dpi = 300, figsize=(8, 8))
b = I_val.cpu().data.numpy()
for k in range(9):
    plt.subplot(3,3, k+1)
    plt.imshow(b[k,:].squeeze(0),cmap='gray')
    plt.title('True Label: '+str(labels_val[k].cpu().numpy()))
    plt.axis('off')
plt.show()

# %%
plt.figure(dpi = 300, figsize=(8,8))
plt.subplot(221)
plt.imshow(donn.does[0].height_map.detach().cpu().numpy())    
plt.colorbar()
plt.subplot(222)
plt.imshow(donn.does[1].height_map.detach().cpu().numpy())
plt.colorbar()
plt.subplot(223)
plt.imshow(donn.does[2].height_map.detach().cpu().numpy())
plt.colorbar()
plt.subplot(224)
plt.imshow(donn.does[2].height_map.detach().cpu().numpy())
plt.colorbar()

# %%
import seaborn as sns
matrix, test_acc, I, labels = conf_matrix(donn, test_loader, criterion, iter_frac=1)
# Optionally, plot the confusion matrix using seaborn's heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(matrix, annot=True, fmt="d", cmap="Blues")
plt.xlabel("Predicted Labels")
plt.ylabel("True Labels")
plt.title("Confusion Matrix")
plt.show()

# %%
test_acc
# Out:
# 0.7759098101265823

# %%
np.save('ste_conf_matrix.npy', matrix)

# %%
80 / 256
# Out:
# 0.3125

# %%
# 5. Training the model with different quantized methods

from torch import optim

################ train ###############################
file_path = 'model'
if os.path.exists(file_path) == False:
    os.makedirs(file_path)

device = 'cuda:0' if torch.cuda.is_available() else 'cpu'

donn1 = DONN(input_dxy=input_dxy, 
            input_field_shape=input_field_shape, 
            doe_params=doe_params, 
            optim_params=optim_params,
            wavelengths=wavelengths, 
            num_layer=num_layer,
            d_layer=d_layer, 
            q_method='ste', 
            device=device)

epoch_num = 50
optimizer = optim.AdamW(donn.parameters(), lr=0.1)
criterion = npcc_loss

################################ train ####################################
start_time = time.time()
donn1, train_losses, train_accies, val_losses, val_accies, I_val, labels_val =\
            train(donn1,criterion, optimizer,
                  train_loader,val_loader, 
                  file_path, epoch_num)    
    
end_time = time.time()
print(f'runing time: {end_time - start_time: 5f}s')
# Out:
# The critical distance is [0.04478689] m, the TF will be fine during the sampling !
# The critical distance is [0.04478689] m, the TF will be fine during the sampling !
# The critical distance is [0.04478689] m, the TF will be fine during the sampling !
# The critical distance is [0.04478689] m, the TF will be fine during the sampling !
# The critical distance is [0.04478689] m, the TF will be fine during the sampling !
# epoch 1 200, train loss: -0.020305,train accuracy:  0.083594
#  validation loss:-0.020362, validation accuracy: 0.081641
# epoch 1 400, train loss: -0.020382,train accuracy:  0.082422
#  validation loss:-0.020497, validation accuracy: 0.081250
# epoch 2 200, train loss: -0.020360,train accuracy:  0.082227
#  validation loss:-0.020457, validation accuracy: 0.080469
# epoch 2 400, train loss: -0.020360,train accuracy:  0.083711
#  validation loss:-0.020473, validation accuracy: 0.079102
# epoch 3 200, train loss: -0.020374,train accuracy:  0.082109
#  validation loss:-0.020460, validation accuracy: 0.079297
# epoch 3 400, train loss: -0.020402,train accuracy:  0.084922
#  validation loss:-0.020249, validation accuracy: 0.087109
# epoch 4 200, train loss: -0.020475,train accuracy:  0.086055
#  validation loss:-0.020581, validation accuracy: 0.081445
# epoch 4 400, train loss: -0.020364,train accuracy:  0.081836
#  validation loss:-0.020438, validation accuracy: 0.084375
# epoch 5 200, train loss: -0.020385,train accuracy:  0.081992
#  validation loss:-0.020671, validation accuracy: 0.089453
# epoch 5 400, train loss: -0.020368,train accuracy:  0.085469
#  validation loss:-0.020447, validation accuracy: 0.088867
# epoch 6 200, train loss: -0.020371,train accuracy:  0.082969
#  validation loss:-0.020366, validation accuracy: 0.081250
# epoch 6 400, train loss: -0.020419,train accuracy:  0.083281
#  validation loss:-0.020319, validation accuracy: 0.083008
# epoch 7 200, train loss: -0.020388,train accuracy:  0.083125
#  validation loss:-0.020504, validation accuracy: 0.088281
# epoch 7 400, train loss: -0.020409,train accuracy:  0.085547
#  validation loss:-0.020362, validation accuracy: 0.085742
# epoch 8 200, train loss: -0.020343,train accuracy:  0.079961
#  validation loss:-0.020432, validation accuracy: 0.083789
# epoch 8 400, train loss: -0.020410,train accuracy:  0.084453
#  validation loss:-0.020299, validation accuracy: 0.082031
# KeyboardInterrupt

# %%
plt.figure(dpi = 300, figsize=(8,8))
plt.subplot(221)
plt.imshow(donn.does[0].height_map.detach().cpu().numpy())    
plt.colorbar()
plt.subplot(222)
plt.imshow(donn.does[1].height_map.detach().cpu().numpy())
plt.colorbar()
plt.subplot(223)
plt.imshow(donn.does[2].height_map.detach().cpu().numpy())
plt.colorbar()
plt.subplot(224)
plt.imshow(donn.does[2].height_map.detach().cpu().numpy())
plt.colorbar()

# %%
import seaborn as sns
matrix = conf_matrix(donn, test_loader, criterion, iter_frac=1)
# Optionally, plot the confusion matrix using seaborn's heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(matrix, annot=True, fmt="d", cmap="Blues")
plt.xlabel("Predicted Labels")
plt.ylabel("True Labels")
plt.title("Confusion Matrix")
plt.show()
