# %%
import torch
import sys
sys.path.append('../')
from DataType.ElectricField import ElectricField
from LightSource.Gaussian_beam import Guassian_beam, VectorialGuassian_beam
from utils.Helper_Functions import normalize
from Props.RSC_Prop import *
from Props.CZT_Prop import *
from utils.units import *
from Addons.Polarization import PolarizationAnalyser

# %%
c0 = 2.998e8
f1 = 220e9
f2 = 330e9
wavelength1 = c0 / f1
wavelength2 = c0 / f2

fs = torch.range(f1, f2, 4e9)

wavelengths = c0 / fs
print(wavelengths)

source  = VectorialGuassian_beam(height=200, width=200, 
                        beam_waist_x=10*mm,
                        beam_waist_y=4*mm,
                        jones_vector=[1,-1j],
                        wavelengths=wavelengths, 
                        spacing=[1*mm, 1*mm],
                        alpha=torch.pi/3)
# Out:
# tensor([0.0014, 0.0013, 0.0013, 0.0013, 0.0013, 0.0012, 0.0012, 0.0012, 0.0012,
#         0.0012, 0.0012, 0.0011, 0.0011, 0.0011, 0.0011, 0.0011, 0.0011, 0.0010,
#         0.0010, 0.0010, 0.0010, 0.0010, 0.0010, 0.0010, 0.0009, 0.0009, 0.0009,
#         0.0009])

# %%
out = source()

# %%
out.visualize(wavelength=wavelengths[1], figsize=(8, 12))

# %%
vrs_prop = VRS_prop(z_distance=800 * mm)
field_propagated = vrs_prop.forward(
    field = out
    )
# Out:
# Minimum propagation distance to satisfy energy conservation: 334.777 mm
# Minimum propagation distance to satisfy sampling for FT: 389.250 mm
# The simulation will be accurate !

# %%
field_propagated.visualize(wavelength=wavelengths[1])

# %%
pa = PolarizationAnalyser(field_propagated)

# %%
pa.analyze(wavelength=wavelengths[3], figsize=(6, 6), num_ellipses=(8, 8))

# %%
c0 = 2.998e8
f1 = 220e9
f2 = 330e9
wavelength1 = c0 / f1
wavelength2 = c0 / f2

fs = torch.range(f1, f2, 4e9)

wavelengths = c0 / fs
wavelengths = torch.range(500*nm, 600*nm, 20*nm)
print(wavelengths)

gm = Guassian_beam(height=800, width=800, 
                   beam_waist_x = 20 * um,
                   beam_waist_y = 20 * um,
                   wavelengths=wavelengths, 
                   alpha= torch.pi / 5,
                   spacing=0.6 * um)
field = gm()
    
asm_prop = RSC_prop(z_distance=20 * mm)
czt_prop = CZT_prop(z_distance=20 * mm)
    
field_propagated = asm_prop.forward(
    field = field
    )
# Out:
# tensor([5.0000e-07, 5.2000e-07, 5.4000e-07, 5.6000e-07, 5.8000e-07, 6.0000e-07])
# Minimum propagation distance to satisfy energy conservation: 0.931 mm
# Minimum propagation distance to satisfy sampling for FT: 1.047 mm
# The simulation will be accurate !

# %%
field_propagated.visualize(wavelength=wavelengths[1])

# %%
field_propagated = czt_prop.forward(
    field = field, 
    outputHeight=800,
	outputWidth=1000, 						
	outputPixel_dx=0.6 * um, 
	outputPixel_dy=0.6 * um,
    )
# Out:
# tensor([[[[-0.3253+0.9456j, -0.3398+0.9405j, -0.3535+0.9354j,  ...,
#            -0.3535-0.9354j, -0.3393-0.9407j, -0.3252-0.9456j],
#           [-0.3253+0.9456j, -0.3398+0.9405j, -0.3535+0.9354j,  ...,
#            -0.3535-0.9354j, -0.3393-0.9407j, -0.3252-0.9456j],
#           [-0.3253+0.9456j, -0.3398+0.9405j, -0.3535+0.9354j,  ...,
#            -0.3535-0.9354j, -0.3393-0.9407j, -0.3252-0.9456j],
#           ...,
#           [-0.3253+0.9456j, -0.3398+0.9405j, -0.3535+0.9354j,  ...,
#            -0.3535-0.9354j, -0.3393-0.9407j, -0.3252-0.9456j],
#           [-0.3253+0.9456j, -0.3398+0.9405j, -0.3535+0.9354j,  ...,
#            -0.3535-0.9354j, -0.3393-0.9407j, -0.3252-0.9456j],
#           [-0.3253+0.9456j, -0.3398+0.9405j, -0.3535+0.9354j,  ...,
#            -0.3535-0.9354j, -0.3393-0.9407j, -0.3252-0.9456j]],
#
#          [[-0.5813+0.8137j, -0.5932+0.8051j, -0.6045+0.7966j,  ...,
#            -0.6047-0.7965j, -0.5931-0.8051j, -0.5815-0.8136j],
#           [-0.5813+0.8137j, -0.5932+0.8051j, -0.6045+0.7966j,  ...,
#            -0.6047-0.7965j, -0.5931-0.8051j, -0.5815-0.8136j],
#           [-0.5813+0.8137j, -0.5932+0.8051j, -0.6045+0.7966j,  ...,
#            -0.6047-0.7965j, -0.5931-0.8051j, -0.5815-0.8136j],
#           ...,
#           [-0.5813+0.8137j, -0.5932+0.8051j, -0.6045+0.7966j,  ...,
#            -0.6047-0.7965j, -0.5931-0.8051j, -0.5815-0.8136j],
#           [-0.5813+0.8137j, -0.5932+0.8051j, -0.6045+0.7966j,  ...,
#            -0.6047-0.7965j, -0.5931-0.8051j, -0.5815-0.8136j],
#           [-0.5813+0.8137j, -0.5932+0.8051j, -0.6045+0.7966j,  ...,
#            -0.6047-0.7965j, -0.5931-0.8051j, -0.5815-0.8136j]],
#
#          [[-0.7762+0.6304j, -0.7849+0.6196j, -0.7935+0.6086j,  ...,
#            -0.7931-0.6090j, -0.7846-0.6200j, -0.7760-0.6307j],
#           [-0.7762+0.6304j, -0.7849+0.6196j, -0.7935+0.6086j,  ...,
#            -0.7931-0.6090j, -0.7846-0.6200j, -0.7760-0.6307j],
#           [-0.7762+0.6304j, -0.7849+0.6196j, -0.7935+0.6086j,  ...,
#            -0.7931-0.6090j, -0.7846-0.6200j, -0.7760-0.6307j],
#           ...,
#           [-0.7762+0.6304j, -0.7849+0.6196j, -0.7935+0.6086j,  ...,
#            -0.7931-0.6090j, -0.7846-0.6200j, -0.7760-0.6307j],
#           [-0.7762+0.6304j, -0.7849+0.6196j, -0.7935+0.6086j,  ...,
#            -0.7931-0.6090j, -0.7846-0.6200j, -0.7760-0.6307j],
#           [-0.7762+0.6304j, -0.7849+0.6196j, -0.7935+0.6086j,  ...,
#            -0.7931-0.6090j, -0.7846-0.6200j, -0.7760-0.6307j]],
#
#          [[-0.9075+0.4201j, -0.9131+0.4077j, -0.9184+0.3956j,  ...,
#            -0.9183-0.3959j, -0.9129-0.4082j, -0.9073-0.4204j],
#           [-0.9075+0.4201j, -0.9131+0.4077j, -0.9184+0.3956j,  ...,
#            -0.9183-0.3959j, -0.9129-0.4082j, -0.9073-0.4204j],
#           [-0.9075+0.4201j, -0.9131+0.4077j, -0.9184+0.3956j,  ...,
#            -0.9183-0.3959j, -0.9129-0.4082j, -0.9073-0.4204j],
#           ...,
#           [-0.9075+0.4201j, -0.9131+0.4077j, -0.9184+0.3956j,  ...,
#            -0.9183-0.3959j, -0.9129-0.4082j, -0.9073-0.4204j],
#           [-0.9075+0.4201j, -0.9131+0.4077j, -0.9184+0.3956j,  ...,
#            -0.9183-0.3959j, -0.9129-0.4082j, -0.9073-0.4204j],
#           [-0.9075+0.4201j, -0.9131+0.4077j, -0.9184+0.3956j,  ...,
#            -0.9183-0.3959j, -0.9129-0.4082j, -0.9073-0.4204j]],
#
#          [[-0.9796+0.2008j, -0.9822+0.1878j, -0.9845+0.1753j,  ...,
#            -0.9845-0.1752j, -0.9822-0.1879j, -0.9797-0.2006j],
#           [-0.9796+0.2008j, -0.9822+0.1878j, -0.9845+0.1753j,  ...,
#            -0.9845-0.1752j, -0.9822-0.1879j, -0.9797-0.2006j],
#           [-0.9796+0.2008j, -0.9822+0.1878j, -0.9845+0.1753j,  ...,
#            -0.9845-0.1752j, -0.9822-0.1879j, -0.9797-0.2006j],
#           ...,
#           [-0.9796+0.2008j, -0.9822+0.1878j, -0.9845+0.1753j,  ...,
#            -0.9845-0.1752j, -0.9822-0.1879j, -0.9797-0.2006j],
#           [-0.9796+0.2008j, -0.9822+0.1878j, -0.9845+0.1753j,  ...,
#            -0.9845-0.1752j, -0.9822-0.1879j, -0.9797-0.2006j],
#           [-0.9796+0.2008j, -0.9822+0.1878j, -0.9845+0.1753j,  ...,
#            -0.9845-0.1752j, -0.9822-0.1879j, -0.9797-0.2006j]],
#
#          [[-0.9999-0.0142j, -0.9996-0.0271j, -0.9992-0.0393j,  ...,
#            -0.9992+0.0392j, -0.9996+0.0268j, -0.9999+0.0141j],
#           [-0.9999-0.0142j, -0.9996-0.0271j, -0.9992-0.0393j,  ...,
#            -0.9992+0.0392j, -0.9996+0.0268j, -0.9999+0.0141j],
#           [-0.9999-0.0142j, -0.9996-0.0271j, -0.9992-0.0393j,  ...,
#            -0.9992+0.0392j, -0.9996+0.0268j, -0.9999+0.0141j],
#           ...,
#           [-0.9999-0.0142j, -0.9996-0.0271j, -0.9992-0.0393j,  ...,
#            -0.9992+0.0392j, -0.9996+0.0268j, -0.9999+0.0141j],
#           [-0.9999-0.0142j, -0.9996-0.0271j, -0.9992-0.0393j,  ...,
#            -0.9992+0.0392j, -0.9996+0.0268j, -0.9999+0.0141j],
#           [-0.9999-0.0142j, -0.9996-0.0271j, -0.9992-0.0393j,  ...,
#            -0.9992+0.0392j, -0.9996+0.0268j, -0.9999+0.0141j]]]],
#        device='cuda:0')
# tensor([[[[-0.3253+0.9456j, -0.3398+0.9405j, -0.3535+0.9354j,  ...,
#            -0.3535-0.9354j, -0.3393-0.9407j, -0.3252-0.9456j],
#           [-0.3253+0.9456j, -0.3398+0.9405j, -0.3535+0.9354j,  ...,
#            -0.3535-0.9354j, -0.3393-0.9407j, -0.3252-0.9456j],
#           [-0.3253+0.9456j, -0.3398+0.9405j, -0.3535+0.9354j,  ...,
#            -0.3535-0.9354j, -0.3393-0.9407j, -0.3252-0.9456j],
#           ...,
#           [-0.3253+0.9456j, -0.3398+0.9405j, -0.3535+0.9354j,  ...,
#            -0.3535-0.9354j, -0.3393-0.9407j, -0.3252-0.9456j],
#           [-0.3253+0.9456j, -0.3398+0.9405j, -0.3535+0.9354j,  ...,
#            -0.3535-0.9354j, -0.3393-0.9407j, -0.3252-0.9456j],
#           [-0.3253+0.9456j, -0.3398+0.9405j, -0.3535+0.9354j,  ...,
#            -0.3535-0.9354j, -0.3393-0.9407j, -0.3252-0.9456j]],
#
#          [[-0.5813+0.8137j, -0.5932+0.8051j, -0.6045+0.7966j,  ...,
#            -0.6047-0.7965j, -0.5931-0.8051j, -0.5815-0.8136j],
#           [-0.5813+0.8137j, -0.5932+0.8051j, -0.6045+0.7966j,  ...,
#            -0.6047-0.7965j, -0.5931-0.8051j, -0.5815-0.8136j],
#           [-0.5813+0.8137j, -0.5932+0.8051j, -0.6045+0.7966j,  ...,
#            -0.6047-0.7965j, -0.5931-0.8051j, -0.5815-0.8136j],
#           ...,
#           [-0.5813+0.8137j, -0.5932+0.8051j, -0.6045+0.7966j,  ...,
#            -0.6047-0.7965j, -0.5931-0.8051j, -0.5815-0.8136j],
#           [-0.5813+0.8137j, -0.5932+0.8051j, -0.6045+0.7966j,  ...,
#            -0.6047-0.7965j, -0.5931-0.8051j, -0.5815-0.8136j],
#           [-0.5813+0.8137j, -0.5932+0.8051j, -0.6045+0.7966j,  ...,
#            -0.6047-0.7965j, -0.5931-0.8051j, -0.5815-0.8136j]],
#
#          [[-0.7762+0.6304j, -0.7849+0.6196j, -0.7935+0.6086j,  ...,
#            -0.7931-0.6090j, -0.7846-0.6200j, -0.7760-0.6307j],
#           [-0.7762+0.6304j, -0.7849+0.6196j, -0.7935+0.6086j,  ...,
#            -0.7931-0.6090j, -0.7846-0.6200j, -0.7760-0.6307j],
#           [-0.7762+0.6304j, -0.7849+0.6196j, -0.7935+0.6086j,  ...,
#            -0.7931-0.6090j, -0.7846-0.6200j, -0.7760-0.6307j],
#           ...,
#           [-0.7762+0.6304j, -0.7849+0.6196j, -0.7935+0.6086j,  ...,
#            -0.7931-0.6090j, -0.7846-0.6200j, -0.7760-0.6307j],
#           [-0.7762+0.6304j, -0.7849+0.6196j, -0.7935+0.6086j,  ...,
#            -0.7931-0.6090j, -0.7846-0.6200j, -0.7760-0.6307j],
#           [-0.7762+0.6304j, -0.7849+0.6196j, -0.7935+0.6086j,  ...,
#            -0.7931-0.6090j, -0.7846-0.6200j, -0.7760-0.6307j]],
#
#          [[-0.9075+0.4201j, -0.9131+0.4077j, -0.9184+0.3956j,  ...,
#            -0.9183-0.3959j, -0.9129-0.4082j, -0.9073-0.4204j],
#           [-0.9075+0.4201j, -0.9131+0.4077j, -0.9184+0.3956j,  ...,
#            -0.9183-0.3959j, -0.9129-0.4082j, -0.9073-0.4204j],
#           [-0.9075+0.4201j, -0.9131+0.4077j, -0.9184+0.3956j,  ...,
#            -0.9183-0.3959j, -0.9129-0.4082j, -0.9073-0.4204j],
#           ...,
#           [-0.9075+0.4201j, -0.9131+0.4077j, -0.9184+0.3956j,  ...,
#            -0.9183-0.3959j, -0.9129-0.4082j, -0.9073-0.4204j],
#           [-0.9075+0.4201j, -0.9131+0.4077j, -0.9184+0.3956j,  ...,
#            -0.9183-0.3959j, -0.9129-0.4082j, -0.9073-0.4204j],
#           [-0.9075+0.4201j, -0.9131+0.4077j, -0.9184+0.3956j,  ...,
#            -0.9183-0.3959j, -0.9129-0.4082j, -0.9073-0.4204j]],
#
#          [[-0.9796+0.2008j, -0.9822+0.1878j, -0.9845+0.1753j,  ...,
#            -0.9845-0.1752j, -0.9822-0.1879j, -0.9797-0.2006j],
#           [-0.9796+0.2008j, -0.9822+0.1878j, -0.9845+0.1753j,  ...,
#            -0.9845-0.1752j, -0.9822-0.1879j, -0.9797-0.2006j],
#           [-0.9796+0.2008j, -0.9822+0.1878j, -0.9845+0.1753j,  ...,
#            -0.9845-0.1752j, -0.9822-0.1879j, -0.9797-0.2006j],
#           ...,
#           [-0.9796+0.2008j, -0.9822+0.1878j, -0.9845+0.1753j,  ...,
#            -0.9845-0.1752j, -0.9822-0.1879j, -0.9797-0.2006j],
#           [-0.9796+0.2008j, -0.9822+0.1878j, -0.9845+0.1753j,  ...,
#            -0.9845-0.1752j, -0.9822-0.1879j, -0.9797-0.2006j],
#           [-0.9796+0.2008j, -0.9822+0.1878j, -0.9845+0.1753j,  ...,
#            -0.9845-0.1752j, -0.9822-0.1879j, -0.9797-0.2006j]],
#
#          [[-0.9999-0.0142j, -0.9996-0.0271j, -0.9992-0.0393j,  ...,
#            -0.9992+0.0392j, -0.9996+0.0268j, -0.9999+0.0141j],
#           [-0.9999-0.0142j, -0.9996-0.0271j, -0.9992-0.0393j,  ...,
#            -0.9992+0.0392j, -0.9996+0.0268j, -0.9999+0.0141j],
#           [-0.9999-0.0142j, -0.9996-0.0271j, -0.9992-0.0393j,  ...,
#            -0.9992+0.0392j, -0.9996+0.0268j, -0.9999+0.0141j],
#           ...,
#           [-0.9999-0.0142j, -0.9996-0.0271j, -0.9992-0.0393j,  ...,
#            -0.9992+0.0392j, -0.9996+0.0268j, -0.9999+0.0141j],
#           [-0.9999-0.0142j, -0.9996-0.0271j, -0.9992-0.0393j,  ...,
#            -0.9992+0.0392j, -0.9996+0.0268j, -0.9999+0.0141j],
#           [-0.9999-0.0142j, -0.9996-0.0271j, -0.9992-0.0393j,  ...,
#            -0.9992+0.0392j, -0.9996+0.0268j, -0.9999+0.0141j]]]],
#        device='cuda:0')

# %%
field_propagated.visualize(wavelength=wavelengths[1])

# %%
field_propagated.shape
# Out:
# torch.Size([1, 6, 1000, 1000])
