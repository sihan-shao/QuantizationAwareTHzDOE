# %%
import torch
import sys
sys.path.append('../')
from DataType.ElectricField import ElectricField
from LightSource.Gaussian_beam import Guassian_beam, VectorialGuassian_beam
from utils.Helper_Functions import normalize
from Props.RSC_Prop import *
from Props.CZT_Prop import *
from utils.units import *
from Addons.Polarization import PolarizationAnalyser

torch.set_default_dtype(torch.float64)

# %%
c0 = 2.998e8
f1 = 220e9
f2 = 330e9
wavelength1 = c0 / f1
wavelength2 = c0 / f2

fs = torch.range(f1, f2, 4e9)

wavelengths = c0 / fs
print(wavelengths)

source  = VectorialGuassian_beam(height=200, width=200, 
                        beam_waist_x=4*mm,
                        beam_waist_y=4*mm,
                        jones_vector=[1,1-1j],
                        wavelengths=wavelengths, 
                        spacing=[1*mm, 1*mm],
                        alpha=0)
# Out:
# tensor([0.0014, 0.0013, 0.0013, 0.0013, 0.0013, 0.0012, 0.0012, 0.0012, 0.0012,
#         0.0012, 0.0012, 0.0011, 0.0011, 0.0011, 0.0011, 0.0011, 0.0011, 0.0010,
#         0.0010, 0.0010, 0.0010, 0.0010, 0.0010, 0.0010, 0.0009, 0.0009, 0.0009,
#         0.0009])

# %%
out = source()

# %%
out.visualize(wavelength=wavelengths[1], figsize=(8, 12))

# %%
vrs_prop = VRS_prop(z_distance=800 * mm)
field_propagated = vrs_prop.forward(
    field = out
    )
# Out:
# Minimum propagation distance to satisfy energy conservation: 334.776 mm
# Minimum propagation distance to satisfy sampling for FT: 389.250 mm
# The simulation will be accurate !

# %%
field_propagated.visualize(wavelength=wavelengths[1])

# %%
pa = PolarizationAnalyser(field_propagated)

# %%
pa.analyze(wavelength=wavelengths[3], figsize=(6, 6), num_ellipses=(8, 8))

# %%
wavelengths = 1 * mm


gm = Guassian_beam(height=200, width=200, 
                   beam_waist_x = 2*mm,
                   beam_waist_y = 2*mm,
                   wavelengths=wavelengths, 
                   alpha= 0,
                   spacing=1*mm)
field = gm()
    
asm_prop = RSC_prop(z_distance=500 * mm)
czt_prop = CZT_prop(z_distance=500 * mm)
    
field_propagated = asm_prop.forward(
    field = field
    )
# Out:
# Minimum propagation distance to satisfy energy conservation: 283.552 mm
# Minimum propagation distance to satisfy sampling for FT: 346.410 mm
# The simulation will be accurate !

# %%
field_propagated.visualize(wavelength=wavelengths)

# %%
field_propagated_2 = czt_prop.forward(
    field = field, 
    outputHeight=200,
	outputWidth=200, 						
	outputPixel_dx=1*mm, 
	outputPixel_dy=1*mm,
    )
# Out:
# torch.Size([1, 1, 200, 200])
# torch.Size([1, 1, 200, 200])
# torch.Size([1, 1, 512, 200])
# torch.Size([1, 1, 512, 200])
# torch.Size([1, 1, 512, 200])
# tensor([[[[0.4005, 0.4015, 0.4025, 0.4035, 0.4045, 0.4055, 0.4065, 0.4075,
#            0.4085, 0.4095, 0.4105, 0.4115, 0.4125, 0.4135, 0.4145, 0.4155,
#            0.4165, 0.4175, 0.4185, 0.4195, 0.4205, 0.4215, 0.4225, 0.4235,
#            0.4245, 0.4255, 0.4265, 0.4275, 0.4285, 0.4295, 0.4305, 0.4315,
#            0.4325, 0.4335, 0.4345, 0.4355, 0.4365, 0.4375, 0.4385, 0.4395,
#            0.4405, 0.4415, 0.4425, 0.4435, 0.4445, 0.4455, 0.4465, 0.4475,
#            0.4485, 0.4495, 0.4505, 0.4515, 0.4525, 0.4535, 0.4545, 0.4555,
#            0.4565, 0.4575, 0.4585, 0.4595, 0.4605, 0.4615, 0.4625, 0.4635,
#            0.4645, 0.4655, 0.4665, 0.4675, 0.4685, 0.4695, 0.4705, 0.4715,
#            0.4725, 0.4735, 0.4745, 0.4755, 0.4765, 0.4775, 0.4785, 0.4795,
# ...

# %%
field_propagated_2.visualize(wavelength=wavelengths)

# %%
field_propagated.shape
# Out:
# torch.Size([1, 1, 200, 200])

# %% [markdown]
# # Code Example For Phd Application Interview

# %%
import torch
import sys
sys.path.append('../')
from DataType.ElectricField import ElectricField
from LightSource.PlaneWave import PlaneWave, VectorialPlaneWave
from utils.Helper_Functions import normalize
from Props.RSC_Prop import *
from Props.CZT_Prop import *
from utils.units import *
from Components.QuantizedDOE import FixDOEElement
from Addons.Polarization import PolarizationAnalyser

torch.set_default_dtype(torch.float64)

# %%
c0 = 2.998e8
lambdas = torch.tensor([400*nm, 500*nm, 600*nm])
fs = c0 / lambdas

print(fs)

lambdas = torch.arange(400*nm, 700*nm, 25*nm)

Source = PlaneWave(height=1200, width=1200, 
                    theta = 0,
                    phi = 0,
                    wavelengths=lambdas, 
                    spacing= 10 * um)

plane_wave = Source()
# Out:
# tensor([7.4950e+14, 5.9960e+14, 4.9967e+14])

# %%
out = Source()

out.visualize(figsize=(10, 10), wavelength=lambdas[1])

# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2

def draw_circle(img, center, radius, value):
    # Create a Gaussian-like intensity profile for the circle
    # img: The image array where the circle will be drawn
    # center: (x, y) coordinates for the center of the circle
    # radius: Radius of the circle
    # value: Maximum grayscale intensity value for the circle (0 to 1 for grayscale)

    # Create a grid of coordinates representing the image
    y, x = np.ogrid[:img.shape[0], :img.shape[1]]
    
    # Calculate the squared distance from the center of the circle
    distance_squared = (x - center[0])**2 + (y - center[1])**2
    
    # Create a mask with Gaussian intensity distribution
    gaussian_mask = value * np.exp(-distance_squared / (2 * (radius / 2) ** 2))
    
    # Apply the mask to the image, but only within the circle radius
    mask = distance_squared <= radius**2
    img[mask] = np.maximum(img[mask], gaussian_mask[mask])

def generate_image():
    # Create a 1000x1000 grayscale image initialized to zero (black)
    img = np.zeros((1000, 1000), dtype=np.float32)
    
    # Parameters for large central circles
    center_radius = 20  # Radius of the central circles (adjusted to match the image)
    center_value = 1  # Intensity value for the central circles (white)
    center_spacing = 80  # Spacing between centers of large circles (adjusted to match the image)
    
    # Calculate starting positions to center the grid of large circles
    # The goal is to create alternating rows of 4 and 3 circles, repeated three times along the y-axis
    start_x = 500 - (1.5 * center_spacing)  # Starting x position for the grid
    start_y = 500 - (2.5 * center_spacing)  # Starting y position for the grid to ensure centering
    
    # Draw alternating rows of 4 and 3 circles, repeated three times along the y-axis
    for row in range(6):
        y = int(start_y + row * center_spacing)  # Calculate the y position for each row
        if row % 2 == 0:
            # Draw 4 circles in this row
            for i in range(4):
                x = int(start_x + i * center_spacing)
                draw_circle(img, (x, y), center_radius, center_value)
        else:
            # Draw 3 circles in this row, centered between the 4-circle rows
            for i in range(3):
                x = int(start_x + center_spacing / 2 + i * center_spacing)
                draw_circle(img, (x, y), center_radius, center_value)

    # Parameters for smaller circles along the edges
    edge_radius = 15  # Radius of the edge circles
    edge_value = 0.3  # Intensity value for the edge circles (gray)
    edge_spacing = 100  # Spacing between centers of smaller circles (in pixels)
    
    # Draw smaller circles along each side of the image with two columns, starting from the center of each side
    margin = 120  # Distance from the edges to start drawing circles
    column_offset = 80  # Offset for the second column of circles to avoid overlap
    
    # Top side - from center extending to left and right
    for i in range(12):
        x_right = 500 + i * edge_spacing  # Start from the center and extend to the right
        x_left = 500 - i * edge_spacing  # Start from the center and extend to the left
        if x_right < 1000 - margin:
            draw_circle(img, (int(x_right), margin), edge_radius, edge_value)  # Top side, right extension
            draw_circle(img, (int(x_right), margin + column_offset), edge_radius, edge_value+0.3)  # Top side, second column right
        if x_left > margin:
            draw_circle(img, (int(x_left), margin), edge_radius, edge_value)  # Top side, left extension
            draw_circle(img, (int(x_left), margin + column_offset), edge_radius, edge_value+0.3)  # Top side, second column left
    
    # Bottom side - from center extending to left and right
    for i in range(12):
        x_right = 500 + i * edge_spacing  # Start from the center and extend to the right
        x_left = 500 - i * edge_spacing  # Start from the center and extend to the left
        if x_right < 1000 - margin:
            draw_circle(img, (int(x_right), 1000 - margin), edge_radius, edge_value)  # Bottom side, right extension
            draw_circle(img, (int(x_right), 1000 - margin - column_offset), edge_radius, edge_value+0.3)  # Bottom side, second column right
        if x_left > margin:
            draw_circle(img, (int(x_left), 1000 - margin), edge_radius, edge_value)  # Bottom side, left extension
            draw_circle(img, (int(x_left), 1000 - margin - column_offset), edge_radius, edge_value+0.3)  # Bottom side, second column left
    
    # Left side - from center extending to top and bottom
    for i in range(4):
        y_top = 500 - i * edge_spacing  # Start from the center and extend upwards
        y_bottom = 500 + i * edge_spacing  # Start from the center and extend downwards
        if y_top > margin:
            draw_circle(img, (margin, int(y_top)), edge_radius, edge_value)  # Left side, top extension
            draw_circle(img, (margin + column_offset, int(y_top)), edge_radius, edge_value+0.3)  # Left side, second column top
        if y_bottom < 1000 - margin:
            draw_circle(img, (margin, int(y_bottom)), edge_radius, edge_value)  # Left side, bottom extension
            draw_circle(img, (margin + column_offset, int(y_bottom)), edge_radius, edge_value+0.3)  # Left side, second column bottom
    
    # Right side - from center extending to top and bottom
    for i in range(4):
        y_top = 500 - i * edge_spacing  # Start from the center and extend upwards
        y_bottom = 500 + i * edge_spacing  # Start from the center and extend downwards
        if y_top > margin:
            draw_circle(img, (1000 - margin, int(y_top)), edge_radius, edge_value)  # Right side, top extension
            draw_circle(img, (1000 - margin - column_offset, int(y_top)), edge_radius, edge_value+0.3)  # Right side, second column top
        if y_bottom < 1000 - margin:
            draw_circle(img, (1000 - margin, int(y_bottom)), edge_radius, edge_value)  # Right side, bottom extension
            draw_circle(img, (1000 - margin - column_offset, int(y_bottom)), edge_radius, edge_value+0.3)  # Right side, second column bottom
    
    return img

# Generate and display the image in Jupyter Notebook
img = generate_image()

# Pad the image to 2000x2000 with zero constant
img = np.pad(img, pad_width=((100, 100), (100, 100)), mode='constant', constant_values=0)
    

# Display the generated image using matplotlib
plt.imshow(img, cmap='viridis')  # Display as a grayscale image
plt.axis('off')  # Hide the axes for better visualization
plt.show()  # Show the image

# %%
phase = FixDOEElement(height_map=img * 1 * um, 
                    tolerance=0*nm, 
                    material=[2.5, 0])

modulated_field = phase(out)

# %%
phase.visualize(figsize=(6, 6))

# %%
rsc_prop = RSC_prop(z_distance=1 * m)
field_propagated = rsc_prop.forward(
    field = modulated_field
    )
# Out:
# Minimum propagation distance to satisfy energy conservation: 600.026 mm
# Minimum propagation distance to satisfy sampling for FT: 599.880 mm
# The simulation will be accurate !

# %%
field_propagated.visualize(figsize=(10, 10), wavelength=lambdas[0], intensity=True)

field_propagated.visualize(figsize=(10, 10), wavelength=lambdas[1], intensity=True)

field_propagated.visualize(figsize=(10, 10), wavelength=lambdas[-2], intensity=True)

# %%
incoheret_sum_field = torch.sum(field_propagated.data.abs()**2, axis=1)

# %%
plt.imshow(incoheret_sum_field[0, :, :].detach().cpu().numpy())
