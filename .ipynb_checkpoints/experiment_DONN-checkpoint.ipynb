# %%
import torch
import torchvision
from torchvision import transforms
from torchvision.transforms import Resize, ToTensor, Pad
import sys
sys.path.append('../')
from DataType.ElectricField import ElectricField
from LightSource.Gaussian_beam import Guassian_beam
from Props.ASM_Prop import ASM_prop
from Props.RSC_Prop import RSC_prop
from Components.Thin_Lens import Thin_LensElement
from Components.Aperture import ApertureElement
from Components.QuantizedDOE import SoftGumbelQuantizedDOELayerv3 as SoftGumbelQuantizedDOELayer
from Components.QuantizedDOE import NaiveGumbelQuantizedDOELayer
from Components.QuantizedDOE import PSQuantizedDOELayer
from Components.QuantizedDOE import STEQuantizedDOELayer
from Components.QuantizedDOE import FullPrecisionDOELayer
from Components.QuantizedDOE import FixDOEElement
from utils.Helper_Functions import normalize, DOE_xyz_cordinates_Generator
from utils.units import *
import numpy as np
import scipy.io
import os
import time
import torch.nn as nn
import matplotlib.pyplot as plt

# %% [markdown]
# # 1. Set simulation parameters

# %%
# Hologram parameters (high-temp resin)
epsilon = 2.66
tand = 0.003
    
input_field_shape = [100, 100]
input_dxy = 1 * mm
doe_shape = [100, 100]
doe_dxy = 1 * mm
    
    
c0 = 2.998e8
f2 = 300e9  # 0.3 THz

wavelengths = c0 / f2
#print("The number of wavelengths: " +  str(wavelengths.shape[0]))

# all parameters of DOE optimization
doe_params = {
    'doe_size': doe_shape,
    'doe_dxy' : doe_dxy,
    'doe_level': 4,
    'look_up_table': [0*mm, 0.2*mm, 0.4*mm, 0.6*mm],
    'num_unit': None,
    'height_constraint_max': 0.8 * mm,
    'tolerance': 10 * um,  
    'material': [epsilon, tand]
}

optim_params = {
    'c_s': 100,   # a number to boost the score (higher more robust to gumbel noise)
    'tau_max': 2.5, # maximum value of tau
    'tau_min': 1.5  # minimum value of tau
}


# layer num and distance between two layer
num_layer = 4
d_layer = 20 * mm

# training parameter
batch_size = 128

# %% [markdown]
# # 2. Define a 3-layers diffractive optical neural network (DONN)

# %%
class DONN(nn.Module):
    """ simulate a diffractive optical neural network with multiple DOEs
        various quantized optimization method can be used here
    """
    def __init__(self, 
                 input_dxy, 
                 input_field_shape,
                 doe_params, 
                 optim_params,
                 wavelengths, 
                 num_layer, 
                 d_layer,
                 q_method,
                 device='cuda:0'):
        super().__init__()
        
        self.input_dxy = input_dxy
        self.input_field_shape = input_field_shape
        self.doe_params = doe_params
        self.optim_params = optim_params
        
        self.wavelengths = wavelengths

        self.num_layer = num_layer
        self.d_layer = d_layer

        
        self.asm_prop2layer = ASM_prop(z_distance=30 * mm, 
                                       bandlimit_type='exact', 
                                       padding_scale=2, 
                                       bandlimit_kernel=True)

        self.aperture = ApertureElement(aperture_type = 'rect',
                                        aperture_size = 0.08)

        self.device = device

        self.iter_frac = None
        
        # define the difffractive layers
        self.asm_prop_layers = nn.ModuleList([
                                    ASM_prop(z_distance=self.d_layer, 
                                             bandlimit_type='exact', 
                                             padding_scale=2, 
                                             bandlimit_kernel=True) for i in range(self.num_layer)
                                    ])
        if q_method == None:
            self.does = nn.ModuleList([FullPrecisionDOELayer(self.doe_params) for i in range(self.num_layer)])
            
        elif q_method == 'sgs':
            self.does = nn.ModuleList([SoftGumbelQuantizedDOELayer(self.doe_params, self.optim_params) for i in range(self.num_layer)])
            
        elif q_method == 'gs':
            self.does = nn.ModuleList([NaiveGumbelQuantizedDOELayer(self.doe_params, self.optim_params) for i in range(self.num_layer)])
            
        elif q_method == 'psq':
            optim_params = {'c_s': 300,'tau_max': 100,'tau_min': 1}
            self.does = nn.ModuleList([PSQuantizedDOELayer(self.doe_params, optim_params) for i in range(self.num_layer)])
            
        elif q_method == 'ste':
            self.does = nn.ModuleList([STEQuantizedDOELayer(self.doe_params, self.optim_params) for i in range(self.num_layer)])

    def encode_object(self, u):
        # Create plane wave
        amplitude_fields = torch.ones(1, 1, self.input_field_shape[0], self.input_field_shape[1], device=self.device) * u
        phase_fields = torch.zeros_like(amplitude_fields, device=self.device)
        # Combine amplitude and phase to form complex electric fields
        electric_fields = amplitude_fields * torch.exp(1j * phase_fields) # add Batch dimension

        field = ElectricField(
                data=electric_fields, 
                wavelengths=self.wavelengths,
                spacing=self.input_dxy
        )
        
        field = self.asm_prop2layer(field)
        field = self.aperture(field)
        
        return field
    
    def forward(self, u, iter_frac=None):

        self.iter_frac = iter_frac
        field = self.encode_object(u)
        #print(iter_frac)

        for i in range(self.num_layer):
            field = self.does[i](field, self.iter_frac)
            field = self.asm_prop_layers[i](field)
            field = self.aperture(field)
    
        return field

# %%
donn = DONN(input_dxy=input_dxy, 
            input_field_shape=input_field_shape, 
            doe_params=doe_params, 
            optim_params=optim_params,
            wavelengths=wavelengths, 
            num_layer=num_layer,
            d_layer=d_layer, 
            q_method=None)

# %%
donn
# Out:
# DONN(
#   (asm_prop2layer): ASM_prop()
#   (aperture): ApertureElement()
#   (asm_prop_layers): ModuleList(
#     (0-3): 4 x ASM_prop()
#   )
#   (does): ModuleList(
#     (0-3): 4 x FullPrecisionDOELayer()
#   )
# )

# %% [markdown]
# # 3. Define a Label Generator and Dataloader

# %% [markdown]
# ## 3.1 MINST Dataloader

# %%
import torch
import torchvision.transforms as transforms
from PIL import Image

def thresholding(image):
    # Convert image to a PyTorch tensor
    image_tensor = transforms.functional.to_tensor(image)
    
    # Apply a threshold (e.g., 0.5 for the middle intensity in normalized range)
    binary_tensor = (image_tensor > 0.4).float()
    
    # Convert tensor back to PIL image
    return transforms.functional.to_pil_image(binary_tensor)

trans =transforms.Compose([Resize(80), Pad(10), transforms.Lambda(thresholding), ToTensor()])

mnist_train = torchvision.datasets.MNIST(
        root="./data", train=True, transform=trans, download=True)
mnist_test = torchvision.datasets.MNIST(
        root="./data", train=False, transform=trans, download=True) 
train_set, val_set = torch.utils.data.random_split(mnist_train, [len(mnist_train)-5000, 5000])
    
# train, validation and test
train_loader = torch.utils.data.DataLoader(train_set, 
                                           batch_size=batch_size,
                                           shuffle=True, num_workers=8,pin_memory=True)
val_loader = torch.utils.data.DataLoader(val_set, 
                                         batch_size=batch_size,
                                         shuffle=True, num_workers=4)

test_loader = torch.utils.data.DataLoader(mnist_test, 
                                         batch_size=batch_size,
                                         shuffle=True, num_workers=4)

# %%
# Function to visualize images
dataiter = iter(train_loader)
images, labels = next(dataiter)

plt.imshow(images[0, 0, :, :])

len(mnist_test)
# Out:
# 10000

# %% [markdown]
# ## 3.2 Label Gemerator

# %%
def rect(X,w):
    Y = torch.zeros(X.shape)
    Y[torch.abs(X)<w]=1
    return Y.cuda()

L = 100
M = 100
dx = L/M
x1 = torch.linspace(-L/2, L/2, M)
X1, Y1 = torch.meshgrid(x1, x1, indexing='ij')
w = 3
yb = 12
xb = 12

cens = [[-xb, yb],[0, yb], [xb, yb],
        [-xb/2-xb,0],[-xb/2,0],[xb/2,0],[xb/2+xb,0],
        [-xb, -yb],[0, -yb], [xb, -yb]]
cens2 = [] 
w2 = int( w*M/L+1)
# labels = label_generator()
for x, y in cens:
    cens2.append([int(M/2+x/L*M),int(M/2+y/L*M)]) 

def label_generator():

    labels = torch.zeros(10,M,M)
    for k in range(10):
        labels[k] = rect(X1-cens[k][0],w)*rect(Y1-cens[k][1],w)
    return labels.unsqueeze(1)


def eval_accuracy(target, label):
        
    label_hat = torch.zeros(target.size(0), 10).cuda()
    # print(label_hat[:,1].size())
    for k in range(10):
        x, y = cens2[k]
        # label_hat[:,k] = target[:, :, y-w2:y+w2, x-w2:x+w2].sum(dim=(2,3)).squeeze(1)
        label_hat[:,k] = target[:, :, x-w2:x+w2, y-w2:y+w2].sum(dim=(2,3)).squeeze(1)          
    # print(label_hat.size())
    label_hat = label_hat.argmax(1)
    acc = (label_hat == label.cuda()).sum()/label.size(0)
    
    return acc.data, label_hat

# %%
test = torch.tensor([0,1,1,3,4,3,6,7,8,9])
a = label_generator()
target = a[test]
acc = eval_accuracy(target, test)
a = torch.sum(a, axis=0)
plt.imshow(a[0],cmap='gray')

# %% [markdown]
# ## 3.3 define loss function

# %%
def npcc_loss(X, Y):
    X_mean = torch.mean(X, dim=(2,3), keepdim=True)
    Y_mean = torch.mean(Y,dim=(2,3), keepdim=True) 
    a = torch.sum((X - X_mean)*(Y - Y_mean), dim=(2,3), keepdim=True)
    b = torch.sqrt(torch.sum((X - X_mean)**2, dim=(2,3), keepdim=True)
                   *torch.sum((Y - Y_mean)**2, dim=(2,3), keepdim=True))
    npcc = torch.mean(-a/b)
    return npcc

# %% [markdown]
# # 4. Define a train and validation pipelines

# %%
def train(onn,
          criterion, 
          optimizer, 
          train_loader,
          val_loader,
          save_path,
          epoch_num=50,
          device='cuda:0'):
    
    label_set = label_generator()
    train_losses = []
    train_accies = []
    val_losses = []
    val_accies = []

    for epoch in range(1, epoch_num+1):  
        train_loss = 0.0
        acc_sum = 0.0
        for i, data in enumerate(train_loader, 0):
            inputs, labels = data
            inputs = inputs.to(device)
            # labels = labels.to(device)
            targets = label_set[labels]
            targets = targets.to(device)
            optimizer.zero_grad()
            outputs = onn(inputs, iter_frac=epoch/epoch_num)
            I = normalize(torch.abs(outputs.data)**2)
      
            loss = criterion(I, targets)
            loss.backward()

            optimizer.step()

            train_loss += loss.item()
            train_acc, label_hat= eval_accuracy(I ,labels)
            acc_sum += train_acc.item()
           
            if (i+1) % 100 == 0:    # print every 2000 mini-batches
                # acc = accuracy(outputs, labels)
                train_log = f'epoch {epoch } {i+1}, train loss: {train_loss/100: 5f},train accuracy: {acc_sum/100: 5f}'
    
                train_losses.append(train_loss /100)
                train_accies.append(acc_sum/100)
                train_loss = 0.0
                acc_sum = 0.0
                torch.save(onn, save_path+'/onn_full'+str(epoch+1)+'.pt')
                with torch.no_grad():
                    val_loss, val_acc, I_val, labels_val = validation(onn, val_loader,criterion, iter_frac=epoch/epoch_num)
                    val_log =f'validation loss:{val_loss :5f}, validation accuracy: {val_acc:5f}'
                    val_losses.append(val_loss)
                    val_accies.append(val_acc)
                print(train_log,'\n', val_log)
                with open(save_path + '/log.txt', "a", encoding='utf-8') as f:
                    f.write(train_log+'\n')
                    f.write(val_log+'\n')
    return onn, train_losses, train_accies, val_losses, val_accies, I_val, labels_val

# %%
def validation(onn, val_loader,criterion, iter_frac, device='cuda:0'):
    val_loss_sum = .0
    val_acc_sum = .0
    label_set = label_generator()
    for i, data in enumerate(val_loader, 0):
        inputs, labels = data
        inputs = inputs.to(device)
        targets = label_set[labels]
        targets = targets.to(device)
        outputs = onn(inputs, iter_frac)
        I = normalize(torch.abs(outputs.data)**2)
        val_loss = criterion(I, targets)
        val_acc, _= eval_accuracy(I ,labels)
        val_loss_sum += val_loss.item()
        val_acc_sum += val_acc.item()
        
    return val_loss_sum/(i+1), val_acc_sum/(i+1), I, labels


def conf_matrix(onn, val_loader, criterion, iter_frac=1, device='cuda:0'):
    from sklearn.metrics import confusion_matrix
    val_loss_sum = .0
    val_acc_sum = .0
    all_labels = []
    all_preds = []
    label_set = label_generator()
    
    for i, data in enumerate(val_loader, 0):
        inputs, labels = data
        inputs = inputs.to(device)
        targets = label_set[labels]
        targets = targets.to(device)
        outputs = onn(inputs, iter_frac)
        I = normalize(torch.abs(outputs.data)**2)
        val_loss = criterion(I, targets)
        val_acc, preds = eval_accuracy(I, labels)
        
        val_loss_sum += val_loss.item()
        val_acc_sum += val_acc.item()
        
        # Collect the true labels and predictions
        all_labels.append(labels.cpu().numpy())
        all_preds.append(preds.cpu().numpy())
    
    # Convert lists to numpy arrays
    all_labels = np.concatenate(all_labels)
    all_preds = np.concatenate(all_preds)
    
    # Compute confusion matrix
    conf_matrix = confusion_matrix(all_labels, all_preds)
    
    return conf_matrix, val_acc_sum/(i+1), I, labels

# %%
# 5. Training the model with different quantized methods

from torch import optim

################ train ###############################
file_path = 'model'
if os.path.exists(file_path) == False:
    os.makedirs(file_path)

device = 'cuda:0' if torch.cuda.is_available() else 'cpu'

donn = DONN(input_dxy=input_dxy, 
            input_field_shape=input_field_shape, 
            doe_params=doe_params, 
            optim_params=optim_params,
            wavelengths=wavelengths, 
            num_layer=num_layer,
            d_layer=d_layer, 
            q_method=None, 
            device=device)

epoch_num = 50
optimizer = optim.AdamW(donn.parameters(), lr=0.1)
criterion = npcc_loss

################################ train ####################################
start_time = time.time()
donn, train_losses, train_accies, val_losses, val_accies, I_val, labels_val =\
            train(donn,criterion, optimizer,
                  train_loader,val_loader, 
                  file_path, epoch_num)    
    
end_time = time.time()
print(f'runing time: {end_time - start_time: 5f}s')

np.save('full_train_loss.npy', np.array(train_losses))
# Out:
# The critical distance is [0.26003873] m, the TF will be fine during the sampling !
# The critical distance is [0.26003873] m, the TF will be fine during the sampling !
# The critical distance is [0.26003873] m, the TF will be fine during the sampling !
# The critical distance is [0.26003873] m, the TF will be fine during the sampling !
# The critical distance is [0.26003873] m, the TF will be fine during the sampling !
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[24], line 29
#      26 ################################ train ####################################
#      27 start_time = time.time()
#      28 donn, train_losses, train_accies, val_losses, val_accies, I_val, labels_val =\
# ---> 29             train(donn,criterion, optimizer,
#      30                   train_loader,val_loader,
#      31                   file_path, epoch_num)
#      33 end_time = time.time()
#      34 print(f'runing time: {end_time - start_time: 5f}s')
#
# Cell In[22], line 34, in train(onn, criterion, optimizer, train_loader, val_loader, save_path, epoch_num, device)
#      30 loss.backward()
#      32 optimizer.step()
# ---> 34 train_loss += loss.item()
#      35 train_acc, label_hat= eval_accuracy(I ,labels)
#      36 acc_sum += train_acc.item()
#
# KeyboardInterrupt:

# %%
# 5. Training the model with different quantized methods

from torch import optim

################ train ###############################
file_path = 'model'
if os.path.exists(file_path) == False:
    os.makedirs(file_path)

device = 'cuda:0' if torch.cuda.is_available() else 'cpu'

donn = DONN(input_dxy=input_dxy, 
            input_field_shape=input_field_shape, 
            doe_params=doe_params, 
            optim_params=optim_params,
            wavelengths=wavelengths, 
            num_layer=num_layer,
            d_layer=d_layer, 
            q_method='sgs', 
            device=device)

epoch_num = 50
optimizer = optim.AdamW(donn.parameters(), lr=0.1)
criterion = npcc_loss

################################ train ####################################
start_time = time.time()
donn, train_losses, train_accies, val_losses, val_accies, I_val, labels_val =\
            train(donn,criterion, optimizer,
                  train_loader,val_loader, 
                  file_path, epoch_num)    
    
end_time = time.time()
print(f'runing time: {end_time - start_time: 5f}s')

np.save('sgs_train_loss.npy', np.array(train_losses))
# Out:
# The critical distance is [0.26003873] m, the TF will be fine during the sampling !
# The critical distance is [0.26003873] m, the TF will be fine during the sampling !
# The critical distance is [0.26003873] m, the TF will be fine during the sampling !
# The critical distance is [0.26003873] m, the TF will be fine during the sampling !
# The critical distance is [0.26003873] m, the TF will be fine during the sampling !
# epoch 1 100, train loss: -0.508956,train accuracy:  0.684688
#  validation loss:-0.585415, validation accuracy: 0.744922
# epoch 1 200, train loss: -0.602117,train accuracy:  0.793281
#  validation loss:-0.612451, validation accuracy: 0.785742
# epoch 1 300, train loss: -0.617789,train accuracy:  0.792969
#  validation loss:-0.621189, validation accuracy: 0.804492
# epoch 1 400, train loss: -0.624737,train accuracy:  0.799687
#  validation loss:-0.628323, validation accuracy: 0.810547
# epoch 2 100, train loss: -0.631772,train accuracy:  0.809844
#  validation loss:-0.631937, validation accuracy: 0.822070
# epoch 2 200, train loss: -0.633645,train accuracy:  0.814844
#  validation loss:-0.635942, validation accuracy: 0.819336
# epoch 2 300, train loss: -0.637724,train accuracy:  0.816562
#  validation loss:-0.634812, validation accuracy: 0.816211
# epoch 2 400, train loss: -0.633325,train accuracy:  0.813281
#  validation loss:-0.637151, validation accuracy: 0.824219
# epoch 3 100, train loss: -0.637697,train accuracy:  0.811719
#  validation loss:-0.636192, validation accuracy: 0.819727
# epoch 3 200, train loss: -0.640824,train accuracy:  0.820547
#  validation loss:-0.639531, validation accuracy: 0.828906
# epoch 3 300, train loss: -0.640120,train accuracy:  0.818203
#  validation loss:-0.639093, validation accuracy: 0.826172
# epoch 3 400, train loss: -0.641322,train accuracy:  0.822031
#  validation loss:-0.641831, validation accuracy: 0.820703
# epoch 4 100, train loss: -0.639779,train accuracy:  0.817109
#  validation loss:-0.642208, validation accuracy: 0.817969
# epoch 4 200, train loss: -0.644266,train accuracy:  0.822656
#  validation loss:-0.639696, validation accuracy: 0.822461
# epoch 4 300, train loss: -0.644028,train accuracy:  0.818984
#  validation loss:-0.645386, validation accuracy: 0.819141
# epoch 4 400, train loss: -0.641625,train accuracy:  0.819844
#  validation loss:-0.643473, validation accuracy: 0.817969
# epoch 5 100, train loss: -0.640531,train accuracy:  0.815234
#  validation loss:-0.646037, validation accuracy: 0.830078
# epoch 5 200, train loss: -0.642556,train accuracy:  0.821562
#  validation loss:-0.646907, validation accuracy: 0.823633
# epoch 5 300, train loss: -0.646004,train accuracy:  0.826094
#  validation loss:-0.647201, validation accuracy: 0.821875
# epoch 5 400, train loss: -0.648167,train accuracy:  0.826875
#  validation loss:-0.647104, validation accuracy: 0.830664
# epoch 6 100, train loss: -0.646981,train accuracy:  0.822812
#  validation loss:-0.645698, validation accuracy: 0.818750
# epoch 6 200, train loss: -0.646812,train accuracy:  0.823281
#  validation loss:-0.648560, validation accuracy: 0.828516
# epoch 6 300, train loss: -0.646455,train accuracy:  0.820781
#  validation loss:-0.648684, validation accuracy: 0.832422
# epoch 6 400, train loss: -0.646416,train accuracy:  0.821172
#  validation loss:-0.647713, validation accuracy: 0.821875
# epoch 7 100, train loss: -0.644000,train accuracy:  0.819531
#  validation loss:-0.646896, validation accuracy: 0.824805
# epoch 7 200, train loss: -0.645886,train accuracy:  0.817500
#  validation loss:-0.648788, validation accuracy: 0.829297
# epoch 7 300, train loss: -0.651064,train accuracy:  0.824844
#  validation loss:-0.645201, validation accuracy: 0.827148
# epoch 7 400, train loss: -0.647183,train accuracy:  0.827266
#  validation loss:-0.646029, validation accuracy: 0.822070
# epoch 8 100, train loss: -0.649825,train accuracy:  0.822500
#  validation loss:-0.648047, validation accuracy: 0.818945
# epoch 8 200, train loss: -0.647318,train accuracy:  0.821719
#  validation loss:-0.647462, validation accuracy: 0.821289
# epoch 8 300, train loss: -0.648624,train accuracy:  0.823906
#  validation loss:-0.645332, validation accuracy: 0.825391
# epoch 8 400, train loss: -0.645164,train accuracy:  0.819766
#  validation loss:-0.644657, validation accuracy: 0.823828
# epoch 9 100, train loss: -0.646977,train accuracy:  0.822266
#  validation loss:-0.650341, validation accuracy: 0.832812
# epoch 9 200, train loss: -0.649327,train accuracy:  0.822266
#  validation loss:-0.646480, validation accuracy: 0.826758
# epoch 9 300, train loss: -0.648288,train accuracy:  0.822266
#  validation loss:-0.649889, validation accuracy: 0.824023
# epoch 9 400, train loss: -0.649176,train accuracy:  0.827109
#  validation loss:-0.649007, validation accuracy: 0.829883
# epoch 10 100, train loss: -0.647352,train accuracy:  0.825859
#  validation loss:-0.650241, validation accuracy: 0.826172
# epoch 10 200, train loss: -0.650973,train accuracy:  0.824766
#  validation loss:-0.648950, validation accuracy: 0.830078
# epoch 10 300, train loss: -0.650536,train accuracy:  0.821250
#  validation loss:-0.648376, validation accuracy: 0.827148
# epoch 10 400, train loss: -0.648176,train accuracy:  0.819922
#  validation loss:-0.651120, validation accuracy: 0.821289
# epoch 11 100, train loss: -0.647168,train accuracy:  0.822812
#  validation loss:-0.651830, validation accuracy: 0.824414
# epoch 11 200, train loss: -0.647779,train accuracy:  0.824766
#  validation loss:-0.645650, validation accuracy: 0.817773
# epoch 11 300, train loss: -0.649733,train accuracy:  0.825937
#  validation loss:-0.650489, validation accuracy: 0.830273
# epoch 11 400, train loss: -0.653315,train accuracy:  0.823984
#  validation loss:-0.650661, validation accuracy: 0.818945
# epoch 12 100, train loss: -0.646583,train accuracy:  0.822187
#  validation loss:-0.648621, validation accuracy: 0.820898
# epoch 12 200, train loss: -0.653103,train accuracy:  0.828359
#  validation loss:-0.652435, validation accuracy: 0.836328
# epoch 12 300, train loss: -0.648243,train accuracy:  0.816094
#  validation loss:-0.650351, validation accuracy: 0.829688
# epoch 12 400, train loss: -0.650627,train accuracy:  0.826797
#  validation loss:-0.649547, validation accuracy: 0.822656
# epoch 13 100, train loss: -0.652399,train accuracy:  0.830078
#  validation loss:-0.647865, validation accuracy: 0.813086
# epoch 13 200, train loss: -0.648282,train accuracy:  0.820234
#  validation loss:-0.648455, validation accuracy: 0.813281
# epoch 13 300, train loss: -0.650829,train accuracy:  0.823984
#  validation loss:-0.650294, validation accuracy: 0.828906
# epoch 13 400, train loss: -0.646455,train accuracy:  0.822109
#  validation loss:-0.650356, validation accuracy: 0.835352
# epoch 14 100, train loss: -0.652839,train accuracy:  0.826406
#  validation loss:-0.650833, validation accuracy: 0.815625
# epoch 14 200, train loss: -0.649473,train accuracy:  0.827187
#  validation loss:-0.647638, validation accuracy: 0.816602
# epoch 14 300, train loss: -0.649529,train accuracy:  0.822109
#  validation loss:-0.647222, validation accuracy: 0.827148
# epoch 14 400, train loss: -0.649209,train accuracy:  0.825625
#  validation loss:-0.649729, validation accuracy: 0.821875
# epoch 15 100, train loss: -0.649884,train accuracy:  0.827109
#  validation loss:-0.651508, validation accuracy: 0.824023
# epoch 15 200, train loss: -0.650011,train accuracy:  0.825937
#  validation loss:-0.651520, validation accuracy: 0.825977
# epoch 15 300, train loss: -0.648698,train accuracy:  0.819766
#  validation loss:-0.649999, validation accuracy: 0.832227
# epoch 15 400, train loss: -0.651545,train accuracy:  0.823594
#  validation loss:-0.649296, validation accuracy: 0.819531
# epoch 16 100, train loss: -0.649510,train accuracy:  0.823203
#  validation loss:-0.649474, validation accuracy: 0.820508
# epoch 16 200, train loss: -0.650210,train accuracy:  0.827656
#  validation loss:-0.649646, validation accuracy: 0.822266
# epoch 16 300, train loss: -0.648971,train accuracy:  0.827812
#  validation loss:-0.648981, validation accuracy: 0.837109
# epoch 16 400, train loss: -0.647825,train accuracy:  0.821797
#  validation loss:-0.649384, validation accuracy: 0.831445
# epoch 17 100, train loss: -0.644233,train accuracy:  0.817578
#  validation loss:-0.645257, validation accuracy: 0.821680
# epoch 17 200, train loss: -0.646548,train accuracy:  0.824688
#  validation loss:-0.649346, validation accuracy: 0.832422
# epoch 17 300, train loss: -0.649053,train accuracy:  0.826484
#  validation loss:-0.649785, validation accuracy: 0.831641
# epoch 17 400, train loss: -0.649129,train accuracy:  0.823984
#  validation loss:-0.647069, validation accuracy: 0.832227
# epoch 18 100, train loss: -0.644914,train accuracy:  0.824141
#  validation loss:-0.647544, validation accuracy: 0.830664
# epoch 18 200, train loss: -0.646850,train accuracy:  0.827891
#  validation loss:-0.644533, validation accuracy: 0.819141
# epoch 18 300, train loss: -0.645349,train accuracy:  0.819922
#  validation loss:-0.645135, validation accuracy: 0.822852
# epoch 18 400, train loss: -0.645757,train accuracy:  0.824531
#  validation loss:-0.646030, validation accuracy: 0.833789
# epoch 19 100, train loss: -0.643280,train accuracy:  0.822969
#  validation loss:-0.644897, validation accuracy: 0.825586
# epoch 19 200, train loss: -0.642623,train accuracy:  0.822344
#  validation loss:-0.644574, validation accuracy: 0.823242
# epoch 19 300, train loss: -0.643168,train accuracy:  0.822891
#  validation loss:-0.645303, validation accuracy: 0.828125
# epoch 19 400, train loss: -0.643397,train accuracy:  0.823047
#  validation loss:-0.643045, validation accuracy: 0.829297
# epoch 20 100, train loss: -0.641853,train accuracy:  0.819453
#  validation loss:-0.639547, validation accuracy: 0.825391
# epoch 20 200, train loss: -0.640251,train accuracy:  0.820156
#  validation loss:-0.636792, validation accuracy: 0.823438
# epoch 20 300, train loss: -0.641322,train accuracy:  0.827812
#  validation loss:-0.640599, validation accuracy: 0.822070
# epoch 20 400, train loss: -0.638052,train accuracy:  0.818750
#  validation loss:-0.640737, validation accuracy: 0.826172
# epoch 21 100, train loss: -0.639992,train accuracy:  0.822812
#  validation loss:-0.633244, validation accuracy: 0.811914
# epoch 21 200, train loss: -0.637120,train accuracy:  0.823516
#  validation loss:-0.637823, validation accuracy: 0.829883
# epoch 21 300, train loss: -0.636392,train accuracy:  0.822734
#  validation loss:-0.633827, validation accuracy: 0.811328
# epoch 21 400, train loss: -0.636020,train accuracy:  0.816719
#  validation loss:-0.636964, validation accuracy: 0.820117
# epoch 22 100, train loss: -0.631928,train accuracy:  0.820391
#  validation loss:-0.633970, validation accuracy: 0.817383
# epoch 22 200, train loss: -0.632227,train accuracy:  0.816250
#  validation loss:-0.632854, validation accuracy: 0.828516
# epoch 22 300, train loss: -0.636403,train accuracy:  0.822187
#  validation loss:-0.635198, validation accuracy: 0.818750
# epoch 22 400, train loss: -0.636539,train accuracy:  0.824063
#  validation loss:-0.631607, validation accuracy: 0.813281
# epoch 23 100, train loss: -0.631758,train accuracy:  0.823047
#  validation loss:-0.626835, validation accuracy: 0.824219
# epoch 23 200, train loss: -0.630106,train accuracy:  0.819609
#  validation loss:-0.629069, validation accuracy: 0.817773
# epoch 23 300, train loss: -0.632367,train accuracy:  0.817813
#  validation loss:-0.630402, validation accuracy: 0.818164
# epoch 23 400, train loss: -0.630772,train accuracy:  0.816641
#  validation loss:-0.632797, validation accuracy: 0.820508
# epoch 24 100, train loss: -0.627599,train accuracy:  0.820469
#  validation loss:-0.625466, validation accuracy: 0.821289
# epoch 24 200, train loss: -0.628590,train accuracy:  0.820469
#  validation loss:-0.628922, validation accuracy: 0.827148
# epoch 24 300, train loss: -0.627348,train accuracy:  0.814688
#  validation loss:-0.628684, validation accuracy: 0.820703
# epoch 24 400, train loss: -0.628555,train accuracy:  0.823984
#  validation loss:-0.626519, validation accuracy: 0.820508
# epoch 25 100, train loss: -0.622936,train accuracy:  0.814297
#  validation loss:-0.623315, validation accuracy: 0.811914
# epoch 25 200, train loss: -0.625534,train accuracy:  0.819688
#  validation loss:-0.618923, validation accuracy: 0.803125
# epoch 25 300, train loss: -0.625114,train accuracy:  0.818828
#  validation loss:-0.622830, validation accuracy: 0.819336
# epoch 25 400, train loss: -0.623910,train accuracy:  0.816094
#  validation loss:-0.621559, validation accuracy: 0.817578
# epoch 26 100, train loss: -0.620325,train accuracy:  0.815312
#  validation loss:-0.619991, validation accuracy: 0.816992
# epoch 26 200, train loss: -0.620550,train accuracy:  0.820078
#  validation loss:-0.624323, validation accuracy: 0.826953
# epoch 26 300, train loss: -0.621899,train accuracy:  0.819453
#  validation loss:-0.620253, validation accuracy: 0.816602
# epoch 26 400, train loss: -0.621232,train accuracy:  0.818984
#  validation loss:-0.621191, validation accuracy: 0.817187
# epoch 27 100, train loss: -0.619217,train accuracy:  0.818359
#  validation loss:-0.616927, validation accuracy: 0.826758
# epoch 27 200, train loss: -0.617349,train accuracy:  0.817813
#  validation loss:-0.613423, validation accuracy: 0.811719
# epoch 27 300, train loss: -0.616075,train accuracy:  0.811562
#  validation loss:-0.617027, validation accuracy: 0.820898
# epoch 27 400, train loss: -0.615565,train accuracy:  0.813438
#  validation loss:-0.615251, validation accuracy: 0.816406
# epoch 28 100, train loss: -0.611476,train accuracy:  0.811797
#  validation loss:-0.612722, validation accuracy: 0.808398
# epoch 28 200, train loss: -0.613738,train accuracy:  0.819219
#  validation loss:-0.611040, validation accuracy: 0.813281
# epoch 28 300, train loss: -0.612207,train accuracy:  0.813984
#  validation loss:-0.611291, validation accuracy: 0.812109
# epoch 28 400, train loss: -0.614358,train accuracy:  0.814844
#  validation loss:-0.608948, validation accuracy: 0.816602
# epoch 29 100, train loss: -0.606039,train accuracy:  0.809141
#  validation loss:-0.609602, validation accuracy: 0.818945
# epoch 29 200, train loss: -0.610310,train accuracy:  0.818516
#  validation loss:-0.607529, validation accuracy: 0.813281
# epoch 29 300, train loss: -0.613325,train accuracy:  0.817656
#  validation loss:-0.611119, validation accuracy: 0.816211
# epoch 29 400, train loss: -0.609138,train accuracy:  0.812344
#  validation loss:-0.606618, validation accuracy: 0.800781
# epoch 30 100, train loss: -0.608546,train accuracy:  0.816875
#  validation loss:-0.604684, validation accuracy: 0.815234
# epoch 30 200, train loss: -0.605161,train accuracy:  0.812344
#  validation loss:-0.603782, validation accuracy: 0.803906
# epoch 30 300, train loss: -0.603174,train accuracy:  0.810937
#  validation loss:-0.602457, validation accuracy: 0.801172
# epoch 30 400, train loss: -0.604696,train accuracy:  0.812500
#  validation loss:-0.604248, validation accuracy: 0.803711
# epoch 31 100, train loss: -0.597817,train accuracy:  0.805547
#  validation loss:-0.601318, validation accuracy: 0.817773
# epoch 31 200, train loss: -0.603638,train accuracy:  0.813984
#  validation loss:-0.603619, validation accuracy: 0.808594
# epoch 31 300, train loss: -0.601569,train accuracy:  0.815625
#  validation loss:-0.601840, validation accuracy: 0.802148
# epoch 31 400, train loss: -0.604633,train accuracy:  0.812266
#  validation loss:-0.599649, validation accuracy: 0.809180
# epoch 32 100, train loss: -0.599399,train accuracy:  0.807656
#  validation loss:-0.595331, validation accuracy: 0.818750
# epoch 32 200, train loss: -0.597202,train accuracy:  0.809531
#  validation loss:-0.600627, validation accuracy: 0.805078
# epoch 32 300, train loss: -0.596159,train accuracy:  0.814609
#  validation loss:-0.597566, validation accuracy: 0.815430
# epoch 32 400, train loss: -0.597509,train accuracy:  0.812656
#  validation loss:-0.597074, validation accuracy: 0.805664
# epoch 33 100, train loss: -0.593775,train accuracy:  0.809141
#  validation loss:-0.595368, validation accuracy: 0.807813
# epoch 33 200, train loss: -0.595779,train accuracy:  0.814219
#  validation loss:-0.592956, validation accuracy: 0.820703
# epoch 33 300, train loss: -0.590079,train accuracy:  0.805156
#  validation loss:-0.592568, validation accuracy: 0.817773
# epoch 33 400, train loss: -0.593728,train accuracy:  0.808438
#  validation loss:-0.593940, validation accuracy: 0.808789
# epoch 34 100, train loss: -0.587065,train accuracy:  0.804063
#  validation loss:-0.584127, validation accuracy: 0.799609
# epoch 34 200, train loss: -0.590566,train accuracy:  0.810937
#  validation loss:-0.587942, validation accuracy: 0.813672
# epoch 34 300, train loss: -0.590179,train accuracy:  0.809141
#  validation loss:-0.586060, validation accuracy: 0.809766
# epoch 34 400, train loss: -0.586700,train accuracy:  0.807344
#  validation loss:-0.588549, validation accuracy: 0.793555
# epoch 35 100, train loss: -0.584193,train accuracy:  0.804375
#  validation loss:-0.580105, validation accuracy: 0.794336
# epoch 35 200, train loss: -0.585173,train accuracy:  0.815078
#  validation loss:-0.582588, validation accuracy: 0.806641
# epoch 35 300, train loss: -0.583436,train accuracy:  0.804375
#  validation loss:-0.583959, validation accuracy: 0.801367
# epoch 35 400, train loss: -0.583328,train accuracy:  0.803906
#  validation loss:-0.585091, validation accuracy: 0.809570
# epoch 36 100, train loss: -0.580800,train accuracy:  0.806406
#  validation loss:-0.578714, validation accuracy: 0.806641
# epoch 36 200, train loss: -0.577793,train accuracy:  0.809141
#  validation loss:-0.576098, validation accuracy: 0.810352
# epoch 36 300, train loss: -0.581407,train accuracy:  0.805937
#  validation loss:-0.577530, validation accuracy: 0.815234
# epoch 36 400, train loss: -0.580798,train accuracy:  0.804375
#  validation loss:-0.581089, validation accuracy: 0.814258
# epoch 37 100, train loss: -0.573939,train accuracy:  0.805156
#  validation loss:-0.573725, validation accuracy: 0.802734
# epoch 37 200, train loss: -0.576236,train accuracy:  0.805156
#  validation loss:-0.573763, validation accuracy: 0.804688
# epoch 37 300, train loss: -0.574575,train accuracy:  0.801484
#  validation loss:-0.574043, validation accuracy: 0.796289
# epoch 37 400, train loss: -0.574684,train accuracy:  0.805156
#  validation loss:-0.575524, validation accuracy: 0.806641
# epoch 38 100, train loss: -0.569911,train accuracy:  0.802891
#  validation loss:-0.568047, validation accuracy: 0.795703
# epoch 38 200, train loss: -0.570932,train accuracy:  0.805156
#  validation loss:-0.571363, validation accuracy: 0.807031
# epoch 38 300, train loss: -0.570670,train accuracy:  0.804844
#  validation loss:-0.569792, validation accuracy: 0.797461
# epoch 38 400, train loss: -0.571373,train accuracy:  0.800391
#  validation loss:-0.568520, validation accuracy: 0.803906
# epoch 39 100, train loss: -0.564634,train accuracy:  0.798516
#  validation loss:-0.565579, validation accuracy: 0.806055
# epoch 39 200, train loss: -0.564939,train accuracy:  0.797578
#  validation loss:-0.564964, validation accuracy: 0.807813
# epoch 39 300, train loss: -0.567307,train accuracy:  0.797422
#  validation loss:-0.565308, validation accuracy: 0.813672
# epoch 39 400, train loss: -0.569591,train accuracy:  0.804453
#  validation loss:-0.567015, validation accuracy: 0.805273
# epoch 40 100, train loss: -0.560597,train accuracy:  0.799141
#  validation loss:-0.561321, validation accuracy: 0.804883
# epoch 40 200, train loss: -0.562640,train accuracy:  0.797969
#  validation loss:-0.561932, validation accuracy: 0.798828
# epoch 40 300, train loss: -0.565496,train accuracy:  0.799609
#  validation loss:-0.562775, validation accuracy: 0.798633
# epoch 40 400, train loss: -0.564161,train accuracy:  0.801562
#  validation loss:-0.560073, validation accuracy: 0.799219
# epoch 41 100, train loss: -0.565429,train accuracy:  0.796562
#  validation loss:-0.567332, validation accuracy: 0.808008
# epoch 41 200, train loss: -0.566500,train accuracy:  0.799141
#  validation loss:-0.560935, validation accuracy: 0.798633
# epoch 41 300, train loss: -0.565094,train accuracy:  0.801875
#  validation loss:-0.560601, validation accuracy: 0.797070
# epoch 41 400, train loss: -0.562725,train accuracy:  0.798203
#  validation loss:-0.562891, validation accuracy: 0.804688
# epoch 42 100, train loss: -0.567316,train accuracy:  0.799844
#  validation loss:-0.565004, validation accuracy: 0.792578
# epoch 42 200, train loss: -0.564721,train accuracy:  0.796094
#  validation loss:-0.564725, validation accuracy: 0.789453
# epoch 42 300, train loss: -0.569071,train accuracy:  0.805078
#  validation loss:-0.563509, validation accuracy: 0.789453
# epoch 42 400, train loss: -0.565897,train accuracy:  0.797422
#  validation loss:-0.566065, validation accuracy: 0.807617
# epoch 43 100, train loss: -0.567190,train accuracy:  0.797813
#  validation loss:-0.565401, validation accuracy: 0.804297
# epoch 43 200, train loss: -0.568862,train accuracy:  0.795234
#  validation loss:-0.567507, validation accuracy: 0.795117
# epoch 43 300, train loss: -0.565128,train accuracy:  0.797188
#  validation loss:-0.565874, validation accuracy: 0.803711
# epoch 43 400, train loss: -0.571027,train accuracy:  0.805859
#  validation loss:-0.563067, validation accuracy: 0.798242
# epoch 44 100, train loss: -0.568103,train accuracy:  0.801250
#  validation loss:-0.567746, validation accuracy: 0.784570
# epoch 44 200, train loss: -0.570701,train accuracy:  0.803594
#  validation loss:-0.566609, validation accuracy: 0.792773
# epoch 44 300, train loss: -0.570537,train accuracy:  0.799375
#  validation loss:-0.569450, validation accuracy: 0.807227
# epoch 44 400, train loss: -0.568584,train accuracy:  0.801406
#  validation loss:-0.569297, validation accuracy: 0.796484
# epoch 45 100, train loss: -0.570378,train accuracy:  0.801953
#  validation loss:-0.570862, validation accuracy: 0.806836
# epoch 45 200, train loss: -0.571330,train accuracy:  0.800312
#  validation loss:-0.571402, validation accuracy: 0.808984
# epoch 45 300, train loss: -0.572750,train accuracy:  0.800547
#  validation loss:-0.569509, validation accuracy: 0.791602
# epoch 45 400, train loss: -0.571108,train accuracy:  0.795859
#  validation loss:-0.571222, validation accuracy: 0.802148
# epoch 46 100, train loss: -0.570704,train accuracy:  0.802891
#  validation loss:-0.570307, validation accuracy: 0.796289
# epoch 46 200, train loss: -0.571278,train accuracy:  0.797266
#  validation loss:-0.571273, validation accuracy: 0.807031
# epoch 46 300, train loss: -0.569937,train accuracy:  0.797578
#  validation loss:-0.569315, validation accuracy: 0.798242
# epoch 46 400, train loss: -0.572589,train accuracy:  0.800000
#  validation loss:-0.570584, validation accuracy: 0.797461
# epoch 47 100, train loss: -0.574469,train accuracy:  0.803438
#  validation loss:-0.571552, validation accuracy: 0.805078
# epoch 47 200, train loss: -0.569820,train accuracy:  0.799766
#  validation loss:-0.569866, validation accuracy: 0.809961
# epoch 47 300, train loss: -0.571734,train accuracy:  0.800469
#  validation loss:-0.569639, validation accuracy: 0.802344
# epoch 47 400, train loss: -0.572101,train accuracy:  0.799531
#  validation loss:-0.572345, validation accuracy: 0.797070
# epoch 48 100, train loss: -0.572566,train accuracy:  0.802266
#  validation loss:-0.568977, validation accuracy: 0.799609
# epoch 48 200, train loss: -0.571876,train accuracy:  0.800312
#  validation loss:-0.573230, validation accuracy: 0.794727
# epoch 48 300, train loss: -0.572415,train accuracy:  0.802031
#  validation loss:-0.571756, validation accuracy: 0.798633
# epoch 48 400, train loss: -0.572698,train accuracy:  0.797891
#  validation loss:-0.571336, validation accuracy: 0.798633
# epoch 49 100, train loss: -0.568720,train accuracy:  0.797031
#  validation loss:-0.572813, validation accuracy: 0.805469
# epoch 49 200, train loss: -0.573604,train accuracy:  0.797969
#  validation loss:-0.574097, validation accuracy: 0.798828
# epoch 49 300, train loss: -0.572652,train accuracy:  0.796719
#  validation loss:-0.573491, validation accuracy: 0.804492
# epoch 49 400, train loss: -0.574838,train accuracy:  0.798984
#  validation loss:-0.572491, validation accuracy: 0.798047
# epoch 50 100, train loss: -0.572533,train accuracy:  0.797500
#  validation loss:-0.572731, validation accuracy: 0.801172
# epoch 50 200, train loss: -0.573077,train accuracy:  0.797031
#  validation loss:-0.572125, validation accuracy: 0.799805
# epoch 50 300, train loss: -0.573961,train accuracy:  0.797578
#  validation loss:-0.573055, validation accuracy: 0.791992
# epoch 50 400, train loss: -0.574609,train accuracy:  0.804531
#  validation loss:-0.573404, validation accuracy: 0.802930
# runing time:  1772.765511s

# %%
# 5. Training the model with different quantized methods

from torch import optim

################ train ###############################
file_path = 'model'
if os.path.exists(file_path) == False:
    os.makedirs(file_path)

device = 'cuda:0' if torch.cuda.is_available() else 'cpu'

donn = DONN(input_dxy=input_dxy, 
            input_field_shape=input_field_shape, 
            doe_params=doe_params, 
            optim_params=optim_params,
            wavelengths=wavelengths, 
            num_layer=num_layer,
            d_layer=d_layer, 
            q_method='gs', 
            device=device)

epoch_num = 50
optimizer = optim.AdamW(donn.parameters(), lr=0.1)
criterion = npcc_loss

################################ train ####################################
start_time = time.time()
donn, train_losses, train_accies, val_losses, val_accies, I_val, labels_val =\
            train(donn,criterion, optimizer,
                  train_loader,val_loader, 
                  file_path, epoch_num)    
    
end_time = time.time()
print(f'runing time: {end_time - start_time: 5f}s')

np.save('gs_train_loss.npy', np.array(train_losses))
# Out:
# The critical distance is [0.26003873] m, the TF will be fine during the sampling !
# The critical distance is [0.26003873] m, the TF will be fine during the sampling !
# The critical distance is [0.26003873] m, the TF will be fine during the sampling !
# The critical distance is [0.26003873] m, the TF will be fine during the sampling !
# The critical distance is [0.26003873] m, the TF will be fine during the sampling !
# epoch 1 100, train loss: -0.139328,train accuracy:  0.253359
#  validation loss:-0.255087, validation accuracy: 0.419141
# epoch 1 200, train loss: -0.345247,train accuracy:  0.546953
#  validation loss:-0.406669, validation accuracy: 0.626953
# epoch 1 300, train loss: -0.438945,train accuracy:  0.664062
#  validation loss:-0.461783, validation accuracy: 0.686719
# epoch 1 400, train loss: -0.478450,train accuracy:  0.714531
#  validation loss:-0.491270, validation accuracy: 0.720117
# epoch 2 100, train loss: -0.500803,train accuracy:  0.735000
#  validation loss:-0.506466, validation accuracy: 0.732031
# epoch 2 200, train loss: -0.510741,train accuracy:  0.741484
#  validation loss:-0.511603, validation accuracy: 0.737109
# epoch 2 300, train loss: -0.514401,train accuracy:  0.742422
#  validation loss:-0.518385, validation accuracy: 0.753906
# epoch 2 400, train loss: -0.520231,train accuracy:  0.751328
#  validation loss:-0.519781, validation accuracy: 0.747461
# epoch 3 100, train loss: -0.524137,train accuracy:  0.751719
#  validation loss:-0.522734, validation accuracy: 0.756055
# epoch 3 200, train loss: -0.528192,train accuracy:  0.759375
#  validation loss:-0.527539, validation accuracy: 0.752539
# epoch 3 300, train loss: -0.527796,train accuracy:  0.758828
#  validation loss:-0.527539, validation accuracy: 0.760547
# epoch 3 400, train loss: -0.529750,train accuracy:  0.760000
#  validation loss:-0.531718, validation accuracy: 0.756445
# epoch 4 100, train loss: -0.530657,train accuracy:  0.759062
#  validation loss:-0.531386, validation accuracy: 0.754687
# epoch 4 200, train loss: -0.533512,train accuracy:  0.766484
#  validation loss:-0.534220, validation accuracy: 0.757422
# epoch 4 300, train loss: -0.533795,train accuracy:  0.761563
#  validation loss:-0.534990, validation accuracy: 0.753906
# epoch 4 400, train loss: -0.537585,train accuracy:  0.767500
#  validation loss:-0.533403, validation accuracy: 0.763477
# epoch 5 100, train loss: -0.536095,train accuracy:  0.764453
#  validation loss:-0.537034, validation accuracy: 0.761133
# epoch 5 200, train loss: -0.536199,train accuracy:  0.760391
#  validation loss:-0.536578, validation accuracy: 0.753906
# epoch 5 300, train loss: -0.538973,train accuracy:  0.769844
#  validation loss:-0.539013, validation accuracy: 0.762109
# epoch 5 400, train loss: -0.540262,train accuracy:  0.775156
#  validation loss:-0.537418, validation accuracy: 0.762109
# epoch 6 100, train loss: -0.539560,train accuracy:  0.768750
#  validation loss:-0.538571, validation accuracy: 0.768555
# epoch 6 200, train loss: -0.539650,train accuracy:  0.764141
#  validation loss:-0.537046, validation accuracy: 0.762109
# epoch 6 300, train loss: -0.539255,train accuracy:  0.765703
#  validation loss:-0.539927, validation accuracy: 0.768945
# epoch 6 400, train loss: -0.540343,train accuracy:  0.773672
#  validation loss:-0.541027, validation accuracy: 0.774023
# epoch 7 100, train loss: -0.538927,train accuracy:  0.766328
#  validation loss:-0.539415, validation accuracy: 0.767383
# epoch 7 200, train loss: -0.542150,train accuracy:  0.768516
#  validation loss:-0.540453, validation accuracy: 0.760352
# epoch 7 300, train loss: -0.541641,train accuracy:  0.774375
#  validation loss:-0.541877, validation accuracy: 0.762500
# epoch 7 400, train loss: -0.542985,train accuracy:  0.773750
#  validation loss:-0.542190, validation accuracy: 0.763281
# epoch 8 100, train loss: -0.544152,train accuracy:  0.772109
#  validation loss:-0.541946, validation accuracy: 0.770703
# epoch 8 200, train loss: -0.541378,train accuracy:  0.768359
#  validation loss:-0.542710, validation accuracy: 0.764062
# epoch 8 300, train loss: -0.542026,train accuracy:  0.766953
#  validation loss:-0.545605, validation accuracy: 0.781055
# epoch 8 400, train loss: -0.543600,train accuracy:  0.769531
#  validation loss:-0.538865, validation accuracy: 0.763086
# epoch 9 100, train loss: -0.543052,train accuracy:  0.770469
#  validation loss:-0.545335, validation accuracy: 0.778320
# epoch 9 200, train loss: -0.543543,train accuracy:  0.769297
#  validation loss:-0.541977, validation accuracy: 0.771094
# epoch 9 300, train loss: -0.542153,train accuracy:  0.772188
#  validation loss:-0.542105, validation accuracy: 0.767578
# epoch 9 400, train loss: -0.543824,train accuracy:  0.770156
#  validation loss:-0.543005, validation accuracy: 0.769336
# epoch 10 100, train loss: -0.545073,train accuracy:  0.767109
#  validation loss:-0.540474, validation accuracy: 0.765234
# epoch 10 200, train loss: -0.543548,train accuracy:  0.768828
#  validation loss:-0.541493, validation accuracy: 0.765039
# epoch 10 300, train loss: -0.544688,train accuracy:  0.768906
#  validation loss:-0.543555, validation accuracy: 0.767578
# epoch 10 400, train loss: -0.544352,train accuracy:  0.771250
#  validation loss:-0.544020, validation accuracy: 0.776563
# epoch 11 100, train loss: -0.544875,train accuracy:  0.771172
#  validation loss:-0.546296, validation accuracy: 0.775195
# epoch 11 200, train loss: -0.546407,train accuracy:  0.767578
#  validation loss:-0.545379, validation accuracy: 0.764062
# epoch 11 300, train loss: -0.543315,train accuracy:  0.769922
#  validation loss:-0.546746, validation accuracy: 0.774219
# epoch 11 400, train loss: -0.546261,train accuracy:  0.772500
#  validation loss:-0.548510, validation accuracy: 0.774023
# epoch 12 100, train loss: -0.544354,train accuracy:  0.769844
#  validation loss:-0.544217, validation accuracy: 0.770703
# epoch 12 200, train loss: -0.543725,train accuracy:  0.767500
#  validation loss:-0.548282, validation accuracy: 0.774414
# epoch 12 300, train loss: -0.547114,train accuracy:  0.769219
#  validation loss:-0.549107, validation accuracy: 0.775586
# epoch 12 400, train loss: -0.550200,train accuracy:  0.780156
#  validation loss:-0.547882, validation accuracy: 0.778711
# epoch 13 100, train loss: -0.546477,train accuracy:  0.771641
#  validation loss:-0.548373, validation accuracy: 0.773828
# epoch 13 200, train loss: -0.545758,train accuracy:  0.770781
#  validation loss:-0.547386, validation accuracy: 0.781250

# %%
# 5. Training the model with different quantized methods

from torch import optim

################ train ###############################
file_path = 'model'
if os.path.exists(file_path) == False:
    os.makedirs(file_path)

device = 'cuda:0' if torch.cuda.is_available() else 'cpu'

donn = DONN(input_dxy=input_dxy, 
            input_field_shape=input_field_shape, 
            doe_params=doe_params, 
            optim_params=optim_params,
            wavelengths=wavelengths, 
            num_layer=num_layer,
            d_layer=d_layer, 
            q_method='ste', 
            device=device)

epoch_num = 50
optimizer = optim.AdamW(donn.parameters(), lr=0.1)
criterion = npcc_loss

################################ train ####################################
start_time = time.time()
donn, train_losses, train_accies, val_losses, val_accies, I_val, labels_val =\
            train(donn,criterion, optimizer,
                  train_loader,val_loader, 
                  file_path, epoch_num)    
    
end_time = time.time()
print(f'runing time: {end_time - start_time: 5f}s')

np.save('ste_train_loss.npy', np.array(train_losses))

# %%
# 5. Training the model with different quantized methods

from torch import optim

################ train ###############################
file_path = 'model'
if os.path.exists(file_path) == False:
    os.makedirs(file_path)

device = 'cuda:0' if torch.cuda.is_available() else 'cpu'

donn = DONN(input_dxy=input_dxy, 
            input_field_shape=input_field_shape, 
            doe_params=doe_params, 
            optim_params=optim_params,
            wavelengths=wavelengths, 
            num_layer=num_layer,
            d_layer=d_layer, 
            q_method='psq', 
            device=device)

epoch_num = 50
optimizer = optim.AdamW(donn.parameters(), lr=0.1)
criterion = npcc_loss

################################ train ####################################
start_time = time.time()
donn, train_losses, train_accies, val_losses, val_accies, I_val, labels_val =\
            train(donn,criterion, optimizer,
                  train_loader,val_loader, 
                  file_path, epoch_num)    
    
end_time = time.time()
print(f'runing time: {end_time - start_time: 5f}s')

np.save('psq_train_loss.npy', np.array(train_losses))
# Out:
# The critical distance is [0.26003873] m, the TF will be fine during the sampling !
# The critical distance is [0.26003873] m, the TF will be fine during the sampling !
# The critical distance is [0.26003873] m, the TF will be fine during the sampling !
# The critical distance is [0.26003873] m, the TF will be fine during the sampling !
# The critical distance is [0.26003873] m, the TF will be fine during the sampling !
# epoch 1 100, train loss: -0.501987,train accuracy:  0.685469
#  validation loss:-0.580025, validation accuracy: 0.767188
# epoch 1 200, train loss: -0.596264,train accuracy:  0.781484
#  validation loss:-0.600834, validation accuracy: 0.785352
# epoch 1 300, train loss: -0.608586,train accuracy:  0.789453
#  validation loss:-0.607414, validation accuracy: 0.770312
# epoch 1 400, train loss: -0.609336,train accuracy:  0.788750
#  validation loss:-0.614206, validation accuracy: 0.800586
# epoch 2 100, train loss: -0.622996,train accuracy:  0.796172
#  validation loss:-0.625256, validation accuracy: 0.795703
# epoch 2 200, train loss: -0.630220,train accuracy:  0.802734
#  validation loss:-0.620311, validation accuracy: 0.780664
# epoch 2 300, train loss: -0.633927,train accuracy:  0.810469
#  validation loss:-0.624649, validation accuracy: 0.788867
# epoch 2 400, train loss: -0.632995,train accuracy:  0.810859
#  validation loss:-0.626066, validation accuracy: 0.784180
# epoch 3 100, train loss: -0.633730,train accuracy:  0.810078
#  validation loss:-0.628738, validation accuracy: 0.789648
# epoch 3 200, train loss: -0.639263,train accuracy:  0.816016
#  validation loss:-0.633207, validation accuracy: 0.797656
# epoch 3 300, train loss: -0.637857,train accuracy:  0.816406
#  validation loss:-0.632119, validation accuracy: 0.797656
# epoch 3 400, train loss: -0.638110,train accuracy:  0.811719
#  validation loss:-0.633737, validation accuracy: 0.801758
# epoch 4 100, train loss: -0.636273,train accuracy:  0.815859
#  validation loss:-0.633127, validation accuracy: 0.808594
# epoch 4 200, train loss: -0.637674,train accuracy:  0.815156
#  validation loss:-0.634717, validation accuracy: 0.805273
# epoch 4 300, train loss: -0.638202,train accuracy:  0.811719
#  validation loss:-0.634281, validation accuracy: 0.798828
# epoch 4 400, train loss: -0.637608,train accuracy:  0.814297
#  validation loss:-0.635290, validation accuracy: 0.806836
# epoch 5 100, train loss: -0.636521,train accuracy:  0.815625
#  validation loss:-0.632505, validation accuracy: 0.806445
# epoch 5 200, train loss: -0.637877,train accuracy:  0.816562
#  validation loss:-0.636007, validation accuracy: 0.810742
# epoch 5 300, train loss: -0.636391,train accuracy:  0.808438
#  validation loss:-0.634992, validation accuracy: 0.803125
# epoch 5 400, train loss: -0.637045,train accuracy:  0.815703
#  validation loss:-0.632346, validation accuracy: 0.803906
# epoch 6 100, train loss: -0.636430,train accuracy:  0.818359
#  validation loss:-0.631965, validation accuracy: 0.812695
# epoch 6 200, train loss: -0.633360,train accuracy:  0.808750
#  validation loss:-0.627603, validation accuracy: 0.814844
# epoch 6 300, train loss: -0.633427,train accuracy:  0.814297
#  validation loss:-0.631085, validation accuracy: 0.816211
# epoch 6 400, train loss: -0.635570,train accuracy:  0.812187
#  validation loss:-0.631305, validation accuracy: 0.801562
# epoch 7 100, train loss: -0.632566,train accuracy:  0.814453
#  validation loss:-0.626795, validation accuracy: 0.796680
# epoch 7 200, train loss: -0.630091,train accuracy:  0.810781
#  validation loss:-0.628135, validation accuracy: 0.804883
# epoch 7 300, train loss: -0.632813,train accuracy:  0.816172
#  validation loss:-0.629448, validation accuracy: 0.808984
# epoch 7 400, train loss: -0.631614,train accuracy:  0.814609
#  validation loss:-0.628152, validation accuracy: 0.809180
# epoch 8 100, train loss: -0.627836,train accuracy:  0.811797
#  validation loss:-0.625321, validation accuracy: 0.810742
# epoch 8 200, train loss: -0.628650,train accuracy:  0.814531
#  validation loss:-0.623606, validation accuracy: 0.797656
# epoch 8 300, train loss: -0.627416,train accuracy:  0.809063
#  validation loss:-0.625292, validation accuracy: 0.813086
# epoch 8 400, train loss: -0.627761,train accuracy:  0.812187
#  validation loss:-0.621143, validation accuracy: 0.800977
# epoch 9 100, train loss: -0.623848,train accuracy:  0.806953
#  validation loss:-0.621569, validation accuracy: 0.803125
# epoch 9 200, train loss: -0.625202,train accuracy:  0.814922
#  validation loss:-0.619924, validation accuracy: 0.798438
# epoch 9 300, train loss: -0.623597,train accuracy:  0.807500
#  validation loss:-0.622613, validation accuracy: 0.803906
# epoch 9 400, train loss: -0.625866,train accuracy:  0.817578
#  validation loss:-0.618122, validation accuracy: 0.810937
# epoch 10 100, train loss: -0.618517,train accuracy:  0.807344
#  validation loss:-0.617451, validation accuracy: 0.809570
# epoch 10 200, train loss: -0.620764,train accuracy:  0.814219
#  validation loss:-0.613101, validation accuracy: 0.797070
# epoch 10 300, train loss: -0.621331,train accuracy:  0.813906
#  validation loss:-0.613879, validation accuracy: 0.801172
# epoch 10 400, train loss: -0.620245,train accuracy:  0.814297
#  validation loss:-0.611351, validation accuracy: 0.790820
# epoch 11 100, train loss: -0.615976,train accuracy:  0.810547
#  validation loss:-0.612729, validation accuracy: 0.803320
# epoch 11 200, train loss: -0.613496,train accuracy:  0.810703
#  validation loss:-0.609630, validation accuracy: 0.797852
# epoch 11 300, train loss: -0.615887,train accuracy:  0.817891
#  validation loss:-0.608411, validation accuracy: 0.803906
# epoch 11 400, train loss: -0.612652,train accuracy:  0.814141
#  validation loss:-0.607891, validation accuracy: 0.805859
# epoch 12 100, train loss: -0.613604,train accuracy:  0.821797
#  validation loss:-0.606006, validation accuracy: 0.799219
# epoch 12 200, train loss: -0.611128,train accuracy:  0.812187
#  validation loss:-0.605003, validation accuracy: 0.798438
# epoch 12 300, train loss: -0.611013,train accuracy:  0.816016
#  validation loss:-0.607251, validation accuracy: 0.804297
# epoch 12 400, train loss: -0.604903,train accuracy:  0.806484
#  validation loss:-0.604852, validation accuracy: 0.806836
# epoch 13 100, train loss: -0.605263,train accuracy:  0.812500
#  validation loss:-0.600854, validation accuracy: 0.800391
# epoch 13 200, train loss: -0.606865,train accuracy:  0.812891
#  validation loss:-0.599530, validation accuracy: 0.802344
# epoch 13 300, train loss: -0.603120,train accuracy:  0.810781
#  validation loss:-0.596532, validation accuracy: 0.794531
# epoch 13 400, train loss: -0.599588,train accuracy:  0.808750
#  validation loss:-0.597971, validation accuracy: 0.800586
# epoch 14 100, train loss: -0.599215,train accuracy:  0.812422
#  validation loss:-0.594611, validation accuracy: 0.800000
# epoch 14 200, train loss: -0.596533,train accuracy:  0.811250
#  validation loss:-0.593280, validation accuracy: 0.800391
# epoch 14 300, train loss: -0.595513,train accuracy:  0.808516
#  validation loss:-0.592537, validation accuracy: 0.799609
# epoch 14 400, train loss: -0.599579,train accuracy:  0.813516
#  validation loss:-0.593959, validation accuracy: 0.800195
# epoch 15 100, train loss: -0.595673,train accuracy:  0.815000
#  validation loss:-0.589370, validation accuracy: 0.795117
# epoch 15 200, train loss: -0.596045,train accuracy:  0.813203
#  validation loss:-0.591061, validation accuracy: 0.805664
# epoch 15 300, train loss: -0.590718,train accuracy:  0.805703
#  validation loss:-0.587607, validation accuracy: 0.801172
# epoch 15 400, train loss: -0.589094,train accuracy:  0.805391
#  validation loss:-0.586017, validation accuracy: 0.794141
# epoch 16 100, train loss: -0.588856,train accuracy:  0.808516
#  validation loss:-0.582150, validation accuracy: 0.796094
# epoch 16 200, train loss: -0.588608,train accuracy:  0.809375
#  validation loss:-0.583571, validation accuracy: 0.795898
# epoch 16 300, train loss: -0.585618,train accuracy:  0.800000
#  validation loss:-0.582619, validation accuracy: 0.790039
# epoch 16 400, train loss: -0.582801,train accuracy:  0.803516
#  validation loss:-0.580489, validation accuracy: 0.792969
# epoch 17 100, train loss: -0.580623,train accuracy:  0.802266
#  validation loss:-0.578981, validation accuracy: 0.794727
# epoch 17 200, train loss: -0.580360,train accuracy:  0.802266
#  validation loss:-0.579423, validation accuracy: 0.792188
# epoch 17 300, train loss: -0.579139,train accuracy:  0.800078
#  validation loss:-0.576509, validation accuracy: 0.791992
# epoch 17 400, train loss: -0.576884,train accuracy:  0.805312
#  validation loss:-0.570169, validation accuracy: 0.794922
# epoch 18 100, train loss: -0.574831,train accuracy:  0.801641
#  validation loss:-0.571700, validation accuracy: 0.790625
# epoch 18 200, train loss: -0.571629,train accuracy:  0.797500
#  validation loss:-0.567050, validation accuracy: 0.788086
# epoch 18 300, train loss: -0.574827,train accuracy:  0.800000
#  validation loss:-0.565858, validation accuracy: 0.783008
# epoch 18 400, train loss: -0.568244,train accuracy:  0.795391
#  validation loss:-0.564250, validation accuracy: 0.777539
# epoch 19 100, train loss: -0.569494,train accuracy:  0.795000
#  validation loss:-0.568295, validation accuracy: 0.785547
# epoch 19 200, train loss: -0.567572,train accuracy:  0.795547
#  validation loss:-0.561895, validation accuracy: 0.785937
# epoch 19 300, train loss: -0.566109,train accuracy:  0.794375
#  validation loss:-0.563063, validation accuracy: 0.782813
# epoch 19 400, train loss: -0.562987,train accuracy:  0.796406
#  validation loss:-0.558177, validation accuracy: 0.778516
# epoch 20 100, train loss: -0.563603,train accuracy:  0.795547
#  validation loss:-0.557911, validation accuracy: 0.790625
# epoch 20 200, train loss: -0.555243,train accuracy:  0.789062
#  validation loss:-0.553324, validation accuracy: 0.788281
# epoch 20 300, train loss: -0.555927,train accuracy:  0.797109
#  validation loss:-0.553482, validation accuracy: 0.785937
# epoch 20 400, train loss: -0.555084,train accuracy:  0.790703
#  validation loss:-0.548442, validation accuracy: 0.785937
# epoch 21 100, train loss: -0.551098,train accuracy:  0.791562
#  validation loss:-0.545547, validation accuracy: 0.779883
# epoch 21 200, train loss: -0.549135,train accuracy:  0.791875
#  validation loss:-0.544844, validation accuracy: 0.783008
# epoch 21 300, train loss: -0.546109,train accuracy:  0.790000
#  validation loss:-0.543567, validation accuracy: 0.783789
# epoch 21 400, train loss: -0.541590,train accuracy:  0.785391
#  validation loss:-0.539541, validation accuracy: 0.775977
# epoch 22 100, train loss: -0.538558,train accuracy:  0.785937
#  validation loss:-0.533904, validation accuracy: 0.776758
# epoch 22 200, train loss: -0.537441,train accuracy:  0.792500
#  validation loss:-0.530989, validation accuracy: 0.780078
# epoch 22 300, train loss: -0.532884,train accuracy:  0.783516
#  validation loss:-0.530166, validation accuracy: 0.777930
# epoch 22 400, train loss: -0.534206,train accuracy:  0.783516
#  validation loss:-0.529192, validation accuracy: 0.778516
# epoch 23 100, train loss: -0.529963,train accuracy:  0.777344
#  validation loss:-0.523245, validation accuracy: 0.763672
# epoch 23 200, train loss: -0.529867,train accuracy:  0.777422
#  validation loss:-0.523621, validation accuracy: 0.764648
# epoch 23 300, train loss: -0.525768,train accuracy:  0.774844
#  validation loss:-0.521727, validation accuracy: 0.770508
# epoch 23 400, train loss: -0.524076,train accuracy:  0.778594
#  validation loss:-0.520057, validation accuracy: 0.773242
# epoch 24 100, train loss: -0.522324,train accuracy:  0.781250
#  validation loss:-0.518101, validation accuracy: 0.765820
# epoch 24 200, train loss: -0.518342,train accuracy:  0.770625
#  validation loss:-0.517720, validation accuracy: 0.768359
# epoch 24 300, train loss: -0.523622,train accuracy:  0.787266
#  validation loss:-0.512791, validation accuracy: 0.762305
# epoch 24 400, train loss: -0.517262,train accuracy:  0.770859
#  validation loss:-0.509705, validation accuracy: 0.755664
# epoch 25 100, train loss: -0.515276,train accuracy:  0.770469
#  validation loss:-0.513068, validation accuracy: 0.757422
# epoch 25 200, train loss: -0.515362,train accuracy:  0.771797
#  validation loss:-0.512456, validation accuracy: 0.766211
# epoch 25 300, train loss: -0.511650,train accuracy:  0.765078
#  validation loss:-0.506889, validation accuracy: 0.755859
# epoch 25 400, train loss: -0.509644,train accuracy:  0.768672
#  validation loss:-0.504889, validation accuracy: 0.755859
# epoch 26 100, train loss: -0.504836,train accuracy:  0.762578
#  validation loss:-0.503168, validation accuracy: 0.751367
# epoch 26 200, train loss: -0.508328,train accuracy:  0.764609
#  validation loss:-0.502579, validation accuracy: 0.761523
# epoch 26 300, train loss: -0.503882,train accuracy:  0.760625
#  validation loss:-0.500851, validation accuracy: 0.758008
# epoch 26 400, train loss: -0.503286,train accuracy:  0.764844
#  validation loss:-0.500330, validation accuracy: 0.755664
# epoch 27 100, train loss: -0.504529,train accuracy:  0.773906
#  validation loss:-0.498901, validation accuracy: 0.762891
# epoch 27 200, train loss: -0.499175,train accuracy:  0.760703
#  validation loss:-0.496087, validation accuracy: 0.753711
# epoch 27 300, train loss: -0.497473,train accuracy:  0.763750
#  validation loss:-0.494546, validation accuracy: 0.753906
# epoch 27 400, train loss: -0.496645,train accuracy:  0.755859
#  validation loss:-0.492515, validation accuracy: 0.745898
# epoch 28 100, train loss: -0.494036,train accuracy:  0.750391
#  validation loss:-0.494588, validation accuracy: 0.755078
# epoch 28 200, train loss: -0.494353,train accuracy:  0.760000
#  validation loss:-0.487866, validation accuracy: 0.747070
# epoch 28 300, train loss: -0.490486,train accuracy:  0.756484
#  validation loss:-0.486437, validation accuracy: 0.748047
# epoch 28 400, train loss: -0.487711,train accuracy:  0.752031
#  validation loss:-0.486096, validation accuracy: 0.748047
# epoch 29 100, train loss: -0.487984,train accuracy:  0.758594
#  validation loss:-0.482303, validation accuracy: 0.755078
# epoch 29 200, train loss: -0.484847,train accuracy:  0.758437
#  validation loss:-0.481206, validation accuracy: 0.757031
# epoch 29 300, train loss: -0.483092,train accuracy:  0.764375
#  validation loss:-0.481598, validation accuracy: 0.756250
# epoch 29 400, train loss: -0.483022,train accuracy:  0.762266
#  validation loss:-0.478619, validation accuracy: 0.752539
# epoch 30 100, train loss: -0.481043,train accuracy:  0.754609
#  validation loss:-0.476388, validation accuracy: 0.742969
# epoch 30 200, train loss: -0.480006,train accuracy:  0.749844
#  validation loss:-0.477958, validation accuracy: 0.749609
# epoch 30 300, train loss: -0.477719,train accuracy:  0.756094
#  validation loss:-0.474939, validation accuracy: 0.748437
# epoch 30 400, train loss: -0.475625,train accuracy:  0.750625
#  validation loss:-0.474078, validation accuracy: 0.748242
# epoch 31 100, train loss: -0.475882,train accuracy:  0.753750
#  validation loss:-0.472237, validation accuracy: 0.749023
# epoch 31 200, train loss: -0.473356,train accuracy:  0.745313
#  validation loss:-0.470193, validation accuracy: 0.740430
# epoch 31 300, train loss: -0.473588,train accuracy:  0.742891
#  validation loss:-0.469513, validation accuracy: 0.736328
# epoch 31 400, train loss: -0.469381,train accuracy:  0.732500
#  validation loss:-0.465291, validation accuracy: 0.728125
# epoch 32 100, train loss: -0.469116,train accuracy:  0.737109
#  validation loss:-0.461116, validation accuracy: 0.728711
# epoch 32 200, train loss: -0.462675,train accuracy:  0.732656
#  validation loss:-0.460438, validation accuracy: 0.735742
# epoch 32 300, train loss: -0.461720,train accuracy:  0.735703
#  validation loss:-0.459332, validation accuracy: 0.725000
# epoch 32 400, train loss: -0.460847,train accuracy:  0.728437
#  validation loss:-0.457963, validation accuracy: 0.728906
# epoch 33 100, train loss: -0.459332,train accuracy:  0.726172
#  validation loss:-0.455119, validation accuracy: 0.727539
# epoch 33 200, train loss: -0.454794,train accuracy:  0.726719
#  validation loss:-0.450093, validation accuracy: 0.724023
# epoch 33 300, train loss: -0.454038,train accuracy:  0.742266
#  validation loss:-0.449258, validation accuracy: 0.734180
# epoch 33 400, train loss: -0.451731,train accuracy:  0.735156
#  validation loss:-0.445358, validation accuracy: 0.731250
# epoch 34 100, train loss: -0.453141,train accuracy:  0.728594
#  validation loss:-0.450433, validation accuracy: 0.731055
# epoch 34 200, train loss: -0.454238,train accuracy:  0.721484
#  validation loss:-0.449275, validation accuracy: 0.711719
# epoch 34 300, train loss: -0.453501,train accuracy:  0.710703
#  validation loss:-0.450406, validation accuracy: 0.711523
# epoch 34 400, train loss: -0.448886,train accuracy:  0.710938
#  validation loss:-0.450641, validation accuracy: 0.708203
# epoch 35 100, train loss: -0.449077,train accuracy:  0.710625
#  validation loss:-0.448866, validation accuracy: 0.716992
# epoch 35 200, train loss: -0.451946,train accuracy:  0.715156
#  validation loss:-0.446051, validation accuracy: 0.706055
# epoch 35 300, train loss: -0.451366,train accuracy:  0.720234
#  validation loss:-0.445536, validation accuracy: 0.711523
# epoch 35 400, train loss: -0.446134,train accuracy:  0.709531
#  validation loss:-0.443595, validation accuracy: 0.711523
# epoch 36 100, train loss: -0.446044,train accuracy:  0.712891
#  validation loss:-0.445794, validation accuracy: 0.718945
# epoch 36 200, train loss: -0.446832,train accuracy:  0.715469
#  validation loss:-0.444697, validation accuracy: 0.709766
# epoch 36 300, train loss: -0.447065,train accuracy:  0.712109
#  validation loss:-0.443300, validation accuracy: 0.705078
# epoch 36 400, train loss: -0.446361,train accuracy:  0.709531
#  validation loss:-0.442821, validation accuracy: 0.707031
# epoch 37 100, train loss: -0.443107,train accuracy:  0.702656
#  validation loss:-0.440616, validation accuracy: 0.695508
# epoch 37 200, train loss: -0.442586,train accuracy:  0.707344
#  validation loss:-0.437804, validation accuracy: 0.695703
# epoch 37 300, train loss: -0.437942,train accuracy:  0.695078
#  validation loss:-0.434589, validation accuracy: 0.690820
# epoch 37 400, train loss: -0.437859,train accuracy:  0.696016
#  validation loss:-0.435438, validation accuracy: 0.695703
# epoch 38 100, train loss: -0.438475,train accuracy:  0.698906
#  validation loss:-0.437036, validation accuracy: 0.687109
# epoch 38 200, train loss: -0.440094,train accuracy:  0.690703
#  validation loss:-0.438415, validation accuracy: 0.685156
# epoch 38 300, train loss: -0.438466,train accuracy:  0.680000
#  validation loss:-0.438353, validation accuracy: 0.690039
# epoch 38 400, train loss: -0.438989,train accuracy:  0.691719
#  validation loss:-0.434140, validation accuracy: 0.681641
# epoch 39 100, train loss: -0.436465,train accuracy:  0.691094
#  validation loss:-0.433863, validation accuracy: 0.689844
# epoch 39 200, train loss: -0.435535,train accuracy:  0.693594
#  validation loss:-0.434259, validation accuracy: 0.693164
# epoch 39 300, train loss: -0.434118,train accuracy:  0.690781
#  validation loss:-0.431470, validation accuracy: 0.675195
# epoch 39 400, train loss: -0.434144,train accuracy:  0.685469
#  validation loss:-0.434887, validation accuracy: 0.687305
# epoch 40 100, train loss: -0.429808,train accuracy:  0.681172
#  validation loss:-0.427546, validation accuracy: 0.674609
# epoch 40 200, train loss: -0.432184,train accuracy:  0.688906
#  validation loss:-0.425891, validation accuracy: 0.669922
# epoch 40 300, train loss: -0.427337,train accuracy:  0.670937
#  validation loss:-0.424624, validation accuracy: 0.686133
# epoch 40 400, train loss: -0.428207,train accuracy:  0.697422
#  validation loss:-0.424021, validation accuracy: 0.697070
# epoch 41 100, train loss: -0.428029,train accuracy:  0.705078
#  validation loss:-0.426488, validation accuracy: 0.707422
# epoch 41 200, train loss: -0.424676,train accuracy:  0.695000
#  validation loss:-0.424390, validation accuracy: 0.688672
# epoch 41 300, train loss: -0.425740,train accuracy:  0.682031
#  validation loss:-0.423238, validation accuracy: 0.684375
# epoch 41 400, train loss: -0.426375,train accuracy:  0.690625
#  validation loss:-0.420810, validation accuracy: 0.682227
# epoch 42 100, train loss: -0.422424,train accuracy:  0.683438
#  validation loss:-0.423181, validation accuracy: 0.692578
# epoch 42 200, train loss: -0.420700,train accuracy:  0.685859
#  validation loss:-0.419039, validation accuracy: 0.679102
# epoch 42 300, train loss: -0.424944,train accuracy:  0.687187
#  validation loss:-0.421407, validation accuracy: 0.676758
# epoch 42 400, train loss: -0.423961,train accuracy:  0.682734
#  validation loss:-0.422968, validation accuracy: 0.667383
# epoch 43 100, train loss: -0.422500,train accuracy:  0.674922
#  validation loss:-0.417031, validation accuracy: 0.662695
# epoch 43 200, train loss: -0.420989,train accuracy:  0.682656
#  validation loss:-0.415683, validation accuracy: 0.670898
# epoch 43 300, train loss: -0.420367,train accuracy:  0.680234
#  validation loss:-0.415045, validation accuracy: 0.669531
# epoch 43 400, train loss: -0.420631,train accuracy:  0.675156
#  validation loss:-0.416908, validation accuracy: 0.661133
# epoch 44 100, train loss: -0.418034,train accuracy:  0.665937
#  validation loss:-0.412994, validation accuracy: 0.657813
# epoch 44 200, train loss: -0.416208,train accuracy:  0.660391
#  validation loss:-0.409038, validation accuracy: 0.650195
# epoch 44 300, train loss: -0.413577,train accuracy:  0.661875
#  validation loss:-0.412031, validation accuracy: 0.657227
# epoch 44 400, train loss: -0.413566,train accuracy:  0.659297
#  validation loss:-0.407643, validation accuracy: 0.645117
# epoch 45 100, train loss: -0.409910,train accuracy:  0.658750
#  validation loss:-0.409642, validation accuracy: 0.645703
# epoch 45 200, train loss: -0.410336,train accuracy:  0.649219
#  validation loss:-0.407783, validation accuracy: 0.635156
# epoch 45 300, train loss: -0.413756,train accuracy:  0.657969
#  validation loss:-0.411757, validation accuracy: 0.649414
# epoch 45 400, train loss: -0.412705,train accuracy:  0.659687
#  validation loss:-0.409712, validation accuracy: 0.652539
# epoch 46 100, train loss: -0.411951,train accuracy:  0.657969
#  validation loss:-0.410621, validation accuracy: 0.660352
# epoch 46 200, train loss: -0.413761,train accuracy:  0.670000
#  validation loss:-0.411692, validation accuracy: 0.673242
# epoch 46 300, train loss: -0.415378,train accuracy:  0.670547
#  validation loss:-0.409592, validation accuracy: 0.658203
# epoch 46 400, train loss: -0.411147,train accuracy:  0.673203
#  validation loss:-0.411844, validation accuracy: 0.667773
# epoch 47 100, train loss: -0.411796,train accuracy:  0.676719
#  validation loss:-0.406940, validation accuracy: 0.664648
# epoch 47 200, train loss: -0.407409,train accuracy:  0.667109
#  validation loss:-0.406722, validation accuracy: 0.673047
# epoch 47 300, train loss: -0.407474,train accuracy:  0.672188
#  validation loss:-0.404284, validation accuracy: 0.664648
# epoch 47 400, train loss: -0.406898,train accuracy:  0.671953
#  validation loss:-0.405270, validation accuracy: 0.663086
# epoch 48 100, train loss: -0.408619,train accuracy:  0.667188
#  validation loss:-0.402444, validation accuracy: 0.663867
# epoch 48 200, train loss: -0.408060,train accuracy:  0.669531
#  validation loss:-0.405665, validation accuracy: 0.664844
# epoch 48 300, train loss: -0.411386,train accuracy:  0.672266
#  validation loss:-0.407421, validation accuracy: 0.658789
# epoch 48 400, train loss: -0.406746,train accuracy:  0.661563
#  validation loss:-0.408497, validation accuracy: 0.673242
# epoch 49 100, train loss: -0.409221,train accuracy:  0.667578
#  validation loss:-0.406958, validation accuracy: 0.662695
# epoch 49 200, train loss: -0.407459,train accuracy:  0.666250
#  validation loss:-0.403446, validation accuracy: 0.661328
# epoch 49 300, train loss: -0.409927,train accuracy:  0.668594
#  validation loss:-0.406399, validation accuracy: 0.660352
# epoch 49 400, train loss: -0.407322,train accuracy:  0.661250
#  validation loss:-0.398958, validation accuracy: 0.648047
# epoch 50 100, train loss: -0.404990,train accuracy:  0.667500
#  validation loss:-0.401625, validation accuracy: 0.661523
# epoch 50 200, train loss: -0.402709,train accuracy:  0.664141
#  validation loss:-0.401022, validation accuracy: 0.667383
# epoch 50 300, train loss: -0.400699,train accuracy:  0.670156
#  validation loss:-0.397219, validation accuracy: 0.653711
# epoch 50 400, train loss: -0.404023,train accuracy:  0.661797
#  validation loss:-0.402186, validation accuracy: 0.659961
# runing time:  1810.693480s

# %%
epochs = [k for k in range(1,epoch_num+1)] 
plt.figure(dpi = 300, figsize=(12,4))
plt.subplot(121)
plt.plot(epochs, train_losses, '-o')
plt.plot(epochs, val_losses, '-s')
plt.xlabel('epoch')
plt.ylabel('Loss')
plt.legend(['train','validation'])
plt.subplot(122)
plt.plot(epochs, train_accies, '-o')
plt.plot(epochs, val_accies, '-s')
plt.xlabel('epoch')
plt.ylabel('Accuracy')
plt.legend(['train','validation'])
plt.show()
    
plt.figure(dpi = 300, figsize=(8, 8))
b = I_val.cpu().data.numpy()
for k in range(9):
    plt.subplot(3,3, k+1)
    plt.imshow(b[k,:].squeeze(0),cmap='gray')
    plt.title('True Label: '+str(labels_val[k].cpu().numpy()))
    plt.axis('off')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[28], line 4
#       2 plt.figure(dpi = 300, figsize=(12,4))
#       3 plt.subplot(121)
# ----> 4 plt.plot(epochs, train_losses, '-o')
#       5 plt.plot(epochs, val_losses, '-s')
#       6 plt.xlabel('epoch')
#
# File /usr/local/lib64/python3.9/site-packages/matplotlib/pyplot.py:3590, in plot(scalex, scaley, data, *args, **kwargs)
#    3582 @_copy_docstring_and_deprecators(Axes.plot)
#    3583 def plot(
#    3584     *args: float | ArrayLike | str,
#    (...)
#    3588     **kwargs,
#    3589 ) -> list[Line2D]:
# -> 3590     return gca().plot(
#    3591         *args,
#    3592         scalex=scalex,
#    3593         scaley=scaley,
#    3594         **({"data": data} if data is not None else {}),
#    3595         **kwargs,
#    3596     )
#
# File /usr/local/lib64/python3.9/site-packages/matplotlib/axes/_axes.py:1724, in Axes.plot(self, scalex, scaley, data, *args, **kwargs)
#    1481 """
#    1482 Plot y versus x as lines and/or markers.
#    1483
#    (...)
#    1721 (``'green'``) or hex strings (``'#008000'``).
#    1722 """
#    1723 kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1724 lines = [*self._get_lines(self, *args, data=data, **kwargs)]
#    1725 for line in lines:
#    1726     self.add_line(line)
#
# File /usr/local/lib64/python3.9/site-packages/matplotlib/axes/_base.py:303, in _process_plot_var_args.__call__(self, axes, data, *args, **kwargs)
#     301     this += args[0],
#     302     args = args[1:]
# --> 303 yield from self._plot_args(
#     304     axes, this, kwargs, ambiguous_fmt_datakey=ambiguous_fmt_datakey)
#
# File /usr/local/lib64/python3.9/site-packages/matplotlib/axes/_base.py:499, in _process_plot_var_args._plot_args(self, axes, tup, kwargs, return_kwargs, ambiguous_fmt_datakey)
#     496     axes.yaxis.update_units(y)
#     498 if x.shape[0] != y.shape[0]:
# --> 499     raise ValueError(f"x and y must have same first dimension, but "
#     500                      f"have shapes {x.shape} and {y.shape}")
#     501 if x.ndim > 2 or y.ndim > 2:
#     502     raise ValueError(f"x and y can be no greater than 2D, but have "
#     503                      f"shapes {x.shape} and {y.shape}")
#
# ValueError: x and y must have same first dimension, but have shapes (50,) and (100,)

# %%
plt.figure(dpi = 300, figsize=(8,8))
plt.subplot(221)
plt.imshow(donn.does[0].height_map.detach().cpu().numpy())    
plt.colorbar()
plt.subplot(222)
plt.imshow(donn.does[1].height_map.detach().cpu().numpy())
plt.colorbar()
plt.subplot(223)
plt.imshow(donn.does[2].height_map.detach().cpu().numpy())
plt.colorbar()
plt.subplot(224)
plt.imshow(donn.does[2].height_map.detach().cpu().numpy())
plt.colorbar()

# %%
import seaborn as sns
matrix, test_acc, I, labels = conf_matrix(donn, test_loader, criterion, iter_frac=1)
# Optionally, plot the confusion matrix using seaborn's heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(matrix, annot=True, fmt="d", cmap="Blues")
plt.xlabel("Predicted Labels")
plt.ylabel("True Labels")
plt.title("Confusion Matrix")
plt.show()

# %%
test_acc
# Out:
# 0.8334651898734177

# %%
np.save('sgs_conf_matrix.npy', matrix)

# %%
acc_list = []

for t in [100, 200, 300, 400, 500, 600]:
    for doe in donn.does:
        doe.tolerance = t * um
    for i in range(20):
        matrix, test_acc, I, labels = conf_matrix(donn, test_loader, criterion, iter_frac=1)
        acc_list.append(test_acc)
        

acc_array = np.array(acc_list).reshape(6, 20)

np.save('acc_array_donn.npy', acc_array)

# %%
acc_array.shape
# Out:
# (6, 20)

# %%
t = 600
for doe in donn.does:
    doe.tolerance = t * um
matrix_600, test_acc, I, labels = conf_matrix(donn, test_loader, criterion, iter_frac=1)

print(test_acc)
# Out:
# 0.09414556962025317

# %%
np.save('sgs_conf_matrix_600um.npy', matrix_600)

# %%
# 5. Training the model with different quantized methods

from torch import optim

################ train ###############################
file_path = 'model'
if os.path.exists(file_path) == False:
    os.makedirs(file_path)

device = 'cuda:0' if torch.cuda.is_available() else 'cpu'

donn1 = DONN(input_dxy=input_dxy, 
            input_field_shape=input_field_shape, 
            doe_params=doe_params, 
            optim_params=optim_params,
            wavelengths=wavelengths, 
            num_layer=num_layer,
            d_layer=d_layer, 
            q_method='ste', 
            device=device)

epoch_num = 50
optimizer = optim.AdamW(donn.parameters(), lr=0.1)
criterion = npcc_loss

################################ train ####################################
start_time = time.time()
donn1, train_losses, train_accies, val_losses, val_accies, I_val, labels_val =\
            train(donn1,criterion, optimizer,
                  train_loader,val_loader, 
                  file_path, epoch_num)    
    
end_time = time.time()
print(f'runing time: {end_time - start_time: 5f}s')
# Out:
# The critical distance is [0.04478689] m, the TF will be fine during the sampling !
# The critical distance is [0.04478689] m, the TF will be fine during the sampling !
# The critical distance is [0.04478689] m, the TF will be fine during the sampling !
# The critical distance is [0.04478689] m, the TF will be fine during the sampling !
# The critical distance is [0.04478689] m, the TF will be fine during the sampling !
# epoch 1 200, train loss: -0.020305,train accuracy:  0.083594
#  validation loss:-0.020362, validation accuracy: 0.081641
# epoch 1 400, train loss: -0.020382,train accuracy:  0.082422
#  validation loss:-0.020497, validation accuracy: 0.081250
# epoch 2 200, train loss: -0.020360,train accuracy:  0.082227
#  validation loss:-0.020457, validation accuracy: 0.080469
# epoch 2 400, train loss: -0.020360,train accuracy:  0.083711
#  validation loss:-0.020473, validation accuracy: 0.079102
# epoch 3 200, train loss: -0.020374,train accuracy:  0.082109
#  validation loss:-0.020460, validation accuracy: 0.079297
# epoch 3 400, train loss: -0.020402,train accuracy:  0.084922
#  validation loss:-0.020249, validation accuracy: 0.087109
# epoch 4 200, train loss: -0.020475,train accuracy:  0.086055
#  validation loss:-0.020581, validation accuracy: 0.081445
# epoch 4 400, train loss: -0.020364,train accuracy:  0.081836
#  validation loss:-0.020438, validation accuracy: 0.084375
# epoch 5 200, train loss: -0.020385,train accuracy:  0.081992
#  validation loss:-0.020671, validation accuracy: 0.089453
# epoch 5 400, train loss: -0.020368,train accuracy:  0.085469
#  validation loss:-0.020447, validation accuracy: 0.088867
# epoch 6 200, train loss: -0.020371,train accuracy:  0.082969
#  validation loss:-0.020366, validation accuracy: 0.081250
# epoch 6 400, train loss: -0.020419,train accuracy:  0.083281
#  validation loss:-0.020319, validation accuracy: 0.083008
# epoch 7 200, train loss: -0.020388,train accuracy:  0.083125
#  validation loss:-0.020504, validation accuracy: 0.088281
# epoch 7 400, train loss: -0.020409,train accuracy:  0.085547
#  validation loss:-0.020362, validation accuracy: 0.085742
# epoch 8 200, train loss: -0.020343,train accuracy:  0.079961
#  validation loss:-0.020432, validation accuracy: 0.083789
# epoch 8 400, train loss: -0.020410,train accuracy:  0.084453
#  validation loss:-0.020299, validation accuracy: 0.082031
# KeyboardInterrupt

# %%
plt.figure(dpi = 300, figsize=(8,8))
plt.subplot(221)
plt.imshow(donn.does[0].height_map.detach().cpu().numpy())    
plt.colorbar()
plt.subplot(222)
plt.imshow(donn.does[1].height_map.detach().cpu().numpy())
plt.colorbar()
plt.subplot(223)
plt.imshow(donn.does[2].height_map.detach().cpu().numpy())
plt.colorbar()
plt.subplot(224)
plt.imshow(donn.does[2].height_map.detach().cpu().numpy())
plt.colorbar()

# %%
import seaborn as sns
matrix = conf_matrix(donn, test_loader, criterion, iter_frac=1)
# Optionally, plot the confusion matrix using seaborn's heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(matrix, annot=True, fmt="d", cmap="Blues")
plt.xlabel("Predicted Labels")
plt.ylabel("True Labels")
plt.title("Confusion Matrix")
plt.show()
